# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# ### Параметры модели

# %%
CLASSES = ['window', 'backgound']
ENCODER = 'resnet50'
ENCODER_WEIGHTS = 'imagenet'
ACTIVATION = 'sigmoid' 
DEVICE = 'cuda'
#DEVICE = 'cpu'
BATCH_SIZE = 10
EPOCHS = 30
x_size = 256
y_size = 256

# %%
# Install required libs
#!pip install -U segmentation-models-pytorch albumentations --user

# %% [markdown]
# ### Загрузка данных

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# !ls /content/gdrive/"My Drive"
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   Files

# %%
# !cp /content/gdrive/'My Drive'/Files/data.zip .
# !unzip data.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: DataSet/data3/train/mask/4605.jpg
#   inflating: DataSet/data3/train/mask/4606.jpg
#   inflating: DataSet/data3/train/mask/4607.jpg
#   inflating: DataSet/data3/train/mask/4608.jpg
#   inflating: DataSet/data3/train/mask/4609.jpg
#   inflating: DataSet/data3/train/mask/4610.jpg
#   inflating: DataSet/data3/train/mask/4611.jpg
#   inflating: DataSet/data3/train/mask/4612.jpg
#   inflating: DataSet/data3/train/mask/4613.jpg
#   inflating: DataSet/data3/train/mask/4614.jpg
#   inflating: DataSet/data3/train/mask/4615.jpg
#   inflating: DataSet/data3/train/mask/4616.jpg
#   inflating: DataSet/data3/train/mask/4617.jpg
#   inflating: DataSet/data3/train/mask/4618.jpg
#   inflating: DataSet/data3/train/mask/4619.jpg
#   inflating: DataSet/data3/train/mask/4620.jpg
#   inflating: DataSet/data3/train/mask/4621.jpg
#   inflating: DataSet/data3/train/mask/4622.jpg
#   inflating: DataSet/data3/train/mask/4623.jpg
#   inflating: DataSet/data3/train/mask/4624.jpg
#   inflating: DataSet/data3/train/mask/4625.jpg
#   inflating: DataSet/data3/train/mask/4626.jpg
#   inflating: DataSet/data3/train/mask/4627.jpg
#   inflating: DataSet/data3/train/mask/4628.jpg
#   inflating: DataSet/data3/train/mask/4629.jpg
#   inflating: DataSet/data3/train/mask/4630.jpg
#   inflating: DataSet/data3/train/mask/4631.jpg
#   inflating: DataSet/data3/train/mask/4632.jpg
#   inflating: DataSet/data3/train/mask/4633.jpg
#   inflating: DataSet/data3/train/mask/4634.jpg
#   inflating: DataSet/data3/train/mask/4635.jpg
#   inflating: DataSet/data3/train/mask/4636.jpg
#   inflating: DataSet/data3/train/mask/4637.jpg
#   inflating: DataSet/data3/train/mask/4638.jpg
#   inflating: DataSet/data3/train/mask/4639.jpg
#   inflating: DataSet/data3/train/mask/4640.jpg
#   inflating: DataSet/data3/train/mask/4641.jpg
#   inflating: DataSet/data3/train/mask/4642.jpg
#   inflating: DataSet/data3/train/mask/4643.jpg
#   inflating: DataSet/data3/train/mask/4644.jpg
#   inflating: DataSet/data3/train/mask/4645.jpg
#   inflating: DataSet/data3/train/mask/4646.jpg
#   inflating: DataSet/data3/train/mask/4647.jpg
#   inflating: DataSet/data3/train/mask/4648.jpg
#   inflating: DataSet/data3/train/mask/4649.jpg
#   inflating: DataSet/data3/train/mask/4650.jpg
#   inflating: DataSet/data3/train/mask/4651.jpg
#   inflating: DataSet/data3/train/mask/4652.jpg
#   inflating: DataSet/data3/train/mask/4653.jpg
#   inflating: DataSet/data3/train/mask/4654.jpg
#   inflating: DataSet/data3/train/mask/4655.jpg
#   inflating: DataSet/data3/train/mask/4656.jpg
#   inflating: DataSet/data3/train/mask/4657.jpg
#   inflating: DataSet/data3/train/mask/4658.jpg
#   inflating: DataSet/data3/train/mask/4659.jpg
#   inflating: DataSet/data3/train/mask/4660.jpg
#   inflating: DataSet/data3/train/mask/4661.jpg
#   inflating: DataSet/data3/train/mask/4662.jpg
#   inflating: DataSet/data3/train/mask/4663.jpg
#   inflating: DataSet/data3/train/mask/4664.jpg
#   inflating: DataSet/data3/train/mask/4665.jpg
#   inflating: DataSet/data3/train/mask/4666.jpg
#   inflating: DataSet/data3/train/mask/4667.jpg
#   inflating: DataSet/data3/train/mask/4668.jpg
#   inflating: DataSet/data3/train/mask/4669.jpg
#   inflating: DataSet/data3/train/mask/4670.jpg
#   inflating: DataSet/data3/train/mask/4671.jpg
#   inflating: DataSet/data3/train/mask/4672.jpg
#   inflating: DataSet/data3/train/mask/4673.jpg
#   inflating: DataSet/data3/train/mask/4674.jpg
#   inflating: DataSet/data3/train/mask/4675.jpg
#   inflating: DataSet/data3/train/mask/4676.jpg
#   inflating: DataSet/data3/train/mask/4677.jpg
#   inflating: DataSet/data3/train/mask/4678.jpg
#   inflating: DataSet/data3/train/mask/4679.jpg
#   inflating: DataSet/data3/train/mask/4680.jpg
#   inflating: DataSet/data3/train/mask/4681.jpg
#   inflating: DataSet/data3/train/mask/4682.jpg
#   inflating: DataSet/data3/train/mask/4683.jpg
#   inflating: DataSet/data3/train/mask/4684.jpg
#   inflating: DataSet/data3/train/mask/4685.jpg
#   inflating: DataSet/data3/train/mask/4686.jpg
#   inflating: DataSet/data3/train/mask/4687.jpg
#   inflating: DataSet/data3/train/mask/4688.jpg
#   inflating: DataSet/data3/train/mask/4689.jpg
#   inflating: DataSet/data3/train/mask/4690.jpg
#   inflating: DataSet/data3/train/mask/4691.jpg
#   inflating: DataSet/data3/train/mask/4692.jpg
#   inflating: DataSet/data3/train/mask/4693.jpg
#   inflating: DataSet/data3/train/mask/4694.jpg
#   inflating: DataSet/data3/train/mask/4695.jpg
#   inflating: DataSet/data3/train/mask/4696.jpg
#   inflating: DataSet/data3/train/mask/4697.jpg
#   inflating: DataSet/data3/train/mask/4698.jpg
#   inflating: DataSet/data3/train/mask/4699.jpg
#   inflating: DataSet/data3/train/mask/4700.jpg
#   inflating: DataSet/data3/train/mask/4701.jpg
#   inflating: DataSet/data3/train/mask/4702.jpg
#   inflating: DataSet/data3/train/mask/4703.jpg
#   inflating: DataSet/data3/train/mask/4704.jpg
#   inflating: DataSet/data3/train/mask/4705.jpg
#   inflating: DataSet/data3/train/mask/4706.jpg
#   inflating: DataSet/data3/train/mask/4707.jpg
#   inflating: DataSet/data3/train/mask/4708.jpg
#   inflating: DataSet/data3/train/mask/4709.jpg
#   inflating: DataSet/data3/train/mask/4710.jpg
#   inflating: DataSet/data3/train/mask/4711.jpg
#   inflating: DataSet/data3/train/mask/4712.jpg
#   inflating: DataSet/data3/train/mask/4713.jpg
#   inflating: DataSet/data3/train/mask/4714.jpg
#   inflating: DataSet/data3/train/mask/4715.jpg
#   inflating: DataSet/data3/train/mask/4716.jpg
#   inflating: DataSet/data3/train/mask/4717.jpg
#   inflating: DataSet/data3/train/mask/4718.jpg
#   inflating: DataSet/data3/train/mask/4719.jpg
#   inflating: DataSet/data3/train/mask/4720.jpg
#   inflating: DataSet/data3/train/mask/4721.jpg
#   inflating: DataSet/data3/train/mask/4722.jpg
#   inflating: DataSet/data3/train/mask/4723.jpg
#   inflating: DataSet/data3/train/mask/4724.jpg
#   inflating: DataSet/data3/train/mask/4725.jpg
#   inflating: DataSet/data3/train/mask/4726.jpg
#   inflating: DataSet/data3/train/mask/4727.jpg
#   inflating: DataSet/data3/train/mask/4728.jpg
#   inflating: DataSet/data3/train/mask/4729.jpg
#   inflating: DataSet/data3/train/mask/4730.jpg
#   inflating: DataSet/data3/train/mask/4731.jpg
#   inflating: DataSet/data3/train/mask/4732.jpg
#   inflating: DataSet/data3/train/mask/4733.jpg
#   inflating: DataSet/data3/train/mask/4734.jpg
#   inflating: DataSet/data3/train/mask/4735.jpg
#   inflating: DataSet/data3/train/mask/4736.jpg
#   inflating: DataSet/data3/train/mask/4737.jpg
#   inflating: DataSet/data3/train/mask/4738.jpg
#   inflating: DataSet/data3/train/mask/4739.jpg
#   inflating: DataSet/data3/train/mask/4740.jpg
#   inflating: DataSet/data3/train/mask/4741.jpg
#   inflating: DataSet/data3/train/mask/4742.jpg
#   inflating: DataSet/data3/train/mask/4743.jpg
#   inflating: DataSet/data3/train/mask/4744.jpg
#   inflating: DataSet/data3/train/mask/4745.jpg
#   inflating: DataSet/data3/train/mask/4746.jpg
#   inflating: DataSet/data3/train/mask/4747.jpg
#   inflating: DataSet/data3/train/mask/4748.jpg
#   inflating: DataSet/data3/train/mask/4749.jpg
#   inflating: DataSet/data3/train/mask/4750.jpg
#   inflating: DataSet/data3/train/mask/4751.jpg
#   inflating: DataSet/data3/train/mask/4752.jpg
#   inflating: DataSet/data3/train/mask/4753.jpg
#   inflating: DataSet/data3/train/mask/4754.jpg
#   inflating: DataSet/data3/train/mask/4755.jpg
#   inflating: DataSet/data3/train/mask/4756.jpg
#   inflating: DataSet/data3/train/mask/4757.jpg
#   inflating: DataSet/data3/train/mask/4758.jpg
#   inflating: DataSet/data3/train/mask/4759.jpg
#   inflating: DataSet/data3/train/mask/4760.jpg
#   inflating: DataSet/data3/train/mask/4761.jpg
#   inflating: DataSet/data3/train/mask/4762.jpg
#   inflating: DataSet/data3/train/mask/4763.jpg
#   inflating: DataSet/data3/train/mask/4764.jpg
#   inflating: DataSet/data3/train/mask/4765.jpg
#   inflating: DataSet/data3/train/mask/4766.jpg
#   inflating: DataSet/data3/train/mask/4767.jpg
#   inflating: DataSet/data3/train/mask/4768.jpg
#   inflating: DataSet/data3/train/mask/4769.jpg
#   inflating: DataSet/data3/train/mask/4770.jpg
#   inflating: DataSet/data3/train/mask/4771.jpg
#   inflating: DataSet/data3/train/mask/4772.jpg
#   inflating: DataSet/data3/train/mask/4773.jpg
#   inflating: DataSet/data3/train/mask/4774.jpg
#   inflating: DataSet/data3/train/mask/4775.jpg
#   inflating: DataSet/data3/train/mask/4776.jpg
#   inflating: DataSet/data3/train/mask/4777.jpg
#   inflating: DataSet/data3/train/mask/4778.jpg
#   inflating: DataSet/data3/train/mask/4779.jpg
#   inflating: DataSet/data3/train/mask/4780.jpg
#   inflating: DataSet/data3/train/mask/4781.jpg
#   inflating: DataSet/data3/train/mask/4782.jpg
#   inflating: DataSet/data3/train/mask/4783.jpg
#   inflating: DataSet/data3/train/mask/4784.jpg
#   inflating: DataSet/data3/train/mask/4785.jpg
#   inflating: DataSet/data3/train/mask/4786.jpg
#   inflating: DataSet/data3/train/mask/4787.jpg
#   inflating: DataSet/data3/train/mask/4788.jpg
#   inflating: DataSet/data3/train/mask/4789.jpg
#   inflating: DataSet/data3/train/mask/4790.jpg
#   inflating: DataSet/data3/train/mask/4791.jpg
#   inflating: DataSet/data3/train/mask/4792.jpg
#   inflating: DataSet/data3/train/mask/4793.jpg
#   inflating: DataSet/data3/train/mask/4794.jpg
#   inflating: DataSet/data3/train/mask/4795.jpg
#   inflating: DataSet/data3/train/mask/4796.jpg
#   inflating: DataSet/data3/train/mask/4797.jpg
#   inflating: DataSet/data3/train/mask/4798.jpg
#   inflating: DataSet/data3/train/mask/4799.jpg
#   inflating: DataSet/data3/train/mask/4800.jpg
#   inflating: DataSet/data3/train/mask/4801.jpg
#   inflating: DataSet/data3/train/mask/4802.jpg
#   inflating: DataSet/data3/train/mask/4803.jpg
#   inflating: DataSet/data3/train/mask/4804.jpg
#   inflating: DataSet/data3/train/mask/4805.jpg
#   inflating: DataSet/data3/train/mask/4806.jpg
#   inflating: DataSet/data3/train/mask/4807.jpg
#   inflating: DataSet/data3/train/mask/4808.jpg
#   inflating: DataSet/data3/train/mask/4809.jpg
#   inflating: DataSet/data3/train/mask/4810.jpg
#   inflating: DataSet/data3/train/mask/4811.jpg
#   inflating: DataSet/data3/train/mask/4812.jpg
#   inflating: DataSet/data3/train/mask/4813.jpg
#   inflating: DataSet/data3/train/mask/4814.jpg
#   inflating: DataSet/data3/train/mask/4815.jpg
#   inflating: DataSet/data3/train/mask/4816.jpg
#   inflating: DataSet/data3/train/mask/4817.jpg
#   inflating: DataSet/data3/train/mask/4818.jpg
#   inflating: DataSet/data3/train/mask/4819.jpg
#   inflating: DataSet/data3/train/mask/4820.jpg
#   inflating: DataSet/data3/train/mask/4821.jpg
#   inflating: DataSet/data3/train/mask/4822.jpg
#   inflating: DataSet/data3/train/mask/4823.jpg
#   inflating: DataSet/data3/train/mask/4824.jpg
#   inflating: DataSet/data3/train/mask/4825.jpg
#   inflating: DataSet/data3/train/mask/4826.jpg
#   inflating: DataSet/data3/train/mask/4827.jpg
#   inflating: DataSet/data3/train/mask/4828.jpg
#   inflating: DataSet/data3/train/mask/4829.jpg
#   inflating: DataSet/data3/train/mask/4830.jpg
#   inflating: DataSet/data3/train/mask/4831.jpg
#   inflating: DataSet/data3/train/mask/4832.jpg
#   inflating: DataSet/data3/train/mask/4833.jpg
#   inflating: DataSet/data3/train/mask/4834.jpg
#   inflating: DataSet/data3/train/mask/4835.jpg
#   inflating: DataSet/data3/train/mask/4836.jpg
#   inflating: DataSet/data3/train/mask/4837.jpg
#   inflating: DataSet/data3/train/mask/4838.jpg
#   inflating: DataSet/data3/train/mask/4839.jpg
#   inflating: DataSet/data3/train/mask/4840.jpg
#   inflating: DataSet/data3/train/mask/4841.jpg
#   inflating: DataSet/data3/train/mask/4842.jpg
#   inflating: DataSet/data3/train/mask/4843.jpg
#   inflating: DataSet/data3/train/mask/4844.jpg
#   inflating: DataSet/data3/train/mask/4845.jpg
#   inflating: DataSet/data3/train/mask/4846.jpg
#   inflating: DataSet/data3/train/mask/4847.jpg
#   inflating: DataSet/data3/train/mask/4848.jpg
#   inflating: DataSet/data3/train/mask/4849.jpg
#   inflating: DataSet/data3/train/mask/4850.jpg
#   inflating: DataSet/data3/train/mask/4851.jpg
#   inflating: DataSet/data3/train/mask/4852.jpg
#   inflating: DataSet/data3/train/mask/4853.jpg
#   inflating: DataSet/data3/train/mask/4854.jpg
#   inflating: DataSet/data3/train/mask/4855.jpg
#   inflating: DataSet/data3/train/mask/4856.jpg
#   inflating: DataSet/data3/train/mask/4857.jpg
#   inflating: DataSet/data3/train/mask/4858.jpg
#   inflating: DataSet/data3/train/mask/4859.jpg
#   inflating: DataSet/data3/train/mask/4860.jpg
#   inflating: DataSet/data3/train/mask/4861.jpg
#   inflating: DataSet/data3/train/mask/4862.jpg
#   inflating: DataSet/data3/train/mask/4863.jpg
#   inflating: DataSet/data3/train/mask/4864.jpg
#   inflating: DataSet/data3/train/mask/4865.jpg
#   inflating: DataSet/data3/train/mask/4866.jpg
#   inflating: DataSet/data3/train/mask/4867.jpg
#   inflating: DataSet/data3/train/mask/4868.jpg
#   inflating: DataSet/data3/train/mask/4869.jpg
#   inflating: DataSet/data3/train/mask/4870.jpg
#   inflating: DataSet/data3/train/mask/4871.jpg
#   inflating: DataSet/data3/train/mask/4872.jpg
#   inflating: DataSet/data3/train/mask/4873.jpg
#   inflating: DataSet/data3/train/mask/4874.jpg
#   inflating: DataSet/data3/train/mask/4875.jpg
#   inflating: DataSet/data3/train/mask/4876.jpg
#   inflating: DataSet/data3/train/mask/4877.jpg
#   inflating: DataSet/data3/train/mask/4878.jpg
#   inflating: DataSet/data3/train/mask/4879.jpg
#   inflating: DataSet/data3/train/mask/4880.jpg
#   inflating: DataSet/data3/train/mask/4881.jpg
#   inflating: DataSet/data3/train/mask/4882.jpg
#   inflating: DataSet/data3/train/mask/4883.jpg
#   inflating: DataSet/data3/train/mask/4884.jpg
#   inflating: DataSet/data3/train/mask/4885.jpg
#   inflating: DataSet/data3/train/mask/4886.jpg
#   inflating: DataSet/data3/train/mask/4887.jpg
#   inflating: DataSet/data3/train/mask/4888.jpg
#   inflating: DataSet/data3/train/mask/4889.jpg
#   inflating: DataSet/data3/train/mask/4890.jpg
#   inflating: DataSet/data3/train/mask/4891.jpg
#   inflating: DataSet/data3/train/mask/4892.jpg
#   inflating: DataSet/data3/train/mask/4893.jpg
#   inflating: DataSet/data3/train/mask/4894.jpg
#   inflating: DataSet/data3/train/mask/4895.jpg
#   inflating: DataSet/data3/train/mask/4896.jpg
#   inflating: DataSet/data3/train/mask/4897.jpg
#   inflating: DataSet/data3/train/mask/4898.jpg
#   inflating: DataSet/data3/train/mask/4899.jpg
#   inflating: DataSet/data3/train/mask/4900.jpg
#   inflating: DataSet/data3/train/mask/4901.jpg
#   inflating: DataSet/data3/train/mask/4902.jpg
#   inflating: DataSet/data3/train/mask/4903.jpg
#   inflating: DataSet/data3/train/mask/4904.jpg
#   inflating: DataSet/data3/train/mask/4905.jpg
#   inflating: DataSet/data3/train/mask/4906.jpg
#   inflating: DataSet/data3/train/mask/4907.jpg
#   inflating: DataSet/data3/train/mask/4908.jpg
#   inflating: DataSet/data3/train/mask/4909.jpg
#   inflating: DataSet/data3/train/mask/4910.jpg
#   inflating: DataSet/data3/train/mask/4911.jpg
#   inflating: DataSet/data3/train/mask/4912.jpg
#   inflating: DataSet/data3/train/mask/4913.jpg
#   inflating: DataSet/data3/train/mask/4914.jpg
#   inflating: DataSet/data3/train/mask/4915.jpg
#   inflating: DataSet/data3/train/mask/4916.jpg
#   inflating: DataSet/data3/train/mask/4917.jpg
#   inflating: DataSet/data3/train/mask/4918.jpg
#   inflating: DataSet/data3/train/mask/4919.jpg
#   inflating: DataSet/data3/train/mask/4920.jpg
#   inflating: DataSet/data3/train/mask/4921.jpg
#   inflating: DataSet/data3/train/mask/4922.jpg
#   inflating: DataSet/data3/train/mask/4923.jpg
#   inflating: DataSet/data3/train/mask/4924.jpg
#   inflating: DataSet/data3/train/mask/4925.jpg
#   inflating: DataSet/data3/train/mask/4926.jpg
#   inflating: DataSet/data3/train/mask/4927.jpg
#   inflating: DataSet/data3/train/mask/4928.jpg
#   inflating: DataSet/data3/train/mask/4929.jpg
#   inflating: DataSet/data3/train/mask/4930.jpg
#   inflating: DataSet/data3/train/mask/4931.jpg
#   inflating: DataSet/data3/train/mask/4932.jpg
#   inflating: DataSet/data3/train/mask/4933.jpg
#   inflating: DataSet/data3/train/mask/4934.jpg
#   inflating: DataSet/data3/train/mask/4935.jpg
#   inflating: DataSet/data3/train/mask/4936.jpg
#   inflating: DataSet/data3/train/mask/4937.jpg
#   inflating: DataSet/data3/train/mask/4938.jpg
#   inflating: DataSet/data3/train/mask/4939.jpg
#   inflating: DataSet/data3/train/mask/4940.jpg
#   inflating: DataSet/data3/train/mask/4941.jpg
#   inflating: DataSet/data3/train/mask/4942.jpg
#   inflating: DataSet/data3/train/mask/4943.jpg
#   inflating: DataSet/data3/train/mask/4944.jpg
#   inflating: DataSet/data3/train/mask/4945.jpg
#   inflating: DataSet/data3/train/mask/4946.jpg
#   inflating: DataSet/data3/train/mask/4947.jpg
#   inflating: DataSet/data3/train/mask/4948.jpg
#   inflating: DataSet/data3/train/mask/4949.jpg
#   inflating: DataSet/data3/train/mask/4950.jpg
#   inflating: DataSet/data3/train/mask/4951.jpg
#   inflating: DataSet/data3/train/mask/4952.jpg
#   inflating: DataSet/data3/train/mask/4953.jpg
#   inflating: DataSet/data3/train/mask/4954.jpg
#   inflating: DataSet/data3/train/mask/4955.jpg
#   inflating: DataSet/data3/train/mask/4956.jpg
#   inflating: DataSet/data3/train/mask/4957.jpg
#   inflating: DataSet/data3/train/mask/4958.jpg
#   inflating: DataSet/data3/train/mask/4959.jpg
#   inflating: DataSet/data3/train/mask/4960.jpg
#   inflating: DataSet/data3/train/mask/4961.jpg
#   inflating: DataSet/data3/train/mask/4962.jpg
#   inflating: DataSet/data3/train/mask/4963.jpg
#   inflating: DataSet/data3/train/mask/4964.jpg
#   inflating: DataSet/data3/train/mask/4965.jpg
#   inflating: DataSet/data3/train/mask/4966.jpg
#   inflating: DataSet/data3/train/mask/4967.jpg
#   inflating: DataSet/data3/train/mask/4968.jpg
#   inflating: DataSet/data3/train/mask/4969.jpg
#   inflating: DataSet/data3/train/mask/4970.jpg
#   inflating: DataSet/data3/train/mask/4971.jpg
#   inflating: DataSet/data3/train/mask/4972.jpg
#   inflating: DataSet/data3/train/mask/4973.jpg
#   inflating: DataSet/data3/train/mask/4974.jpg
#   inflating: DataSet/data3/train/mask/4975.jpg
#   inflating: DataSet/data3/train/mask/4976.jpg
#   inflating: DataSet/data3/train/mask/4977.jpg
#   inflating: DataSet/data3/train/mask/4978.jpg
#   inflating: DataSet/data3/train/mask/4979.jpg
#   inflating: DataSet/data3/train/mask/4980.jpg
#   inflating: DataSet/data3/train/mask/4981.jpg
#   inflating: DataSet/data3/train/mask/4982.jpg
#   inflating: DataSet/data3/train/mask/4983.jpg
#   inflating: DataSet/data3/train/mask/4984.jpg
#   inflating: DataSet/data3/train/mask/4985.jpg
#   inflating: DataSet/data3/train/mask/4986.jpg
#   inflating: DataSet/data3/train/mask/4987.jpg
#   inflating: DataSet/data3/train/mask/4988.jpg
#   inflating: DataSet/data3/train/mask/4989.jpg
#   inflating: DataSet/data3/train/mask/4990.jpg
#   inflating: DataSet/data3/train/mask/4991.jpg
#   inflating: DataSet/data3/train/mask/4992.jpg
#   inflating: DataSet/data3/train/mask/4993.jpg
#   inflating: DataSet/data3/train/mask/4994.jpg
#   inflating: DataSet/data3/train/mask/4995.jpg
#   inflating: DataSet/data3/train/mask/4996.jpg
#   inflating: DataSet/data3/train/mask/4997.jpg
#   inflating: DataSet/data3/train/mask/4998.jpg
#   inflating: DataSet/data3/train/mask/4999.jpg
#   inflating: DataSet/data3/train/mask/5000.jpg
#   inflating: DataSet/data3/train/mask/5001.jpg
#   inflating: DataSet/data3/train/mask/5002.jpg
#   inflating: DataSet/data3/train/mask/5003.jpg
#   inflating: DataSet/data3/train/mask/5004.jpg
#   inflating: DataSet/data3/train/mask/5005.jpg
#   inflating: DataSet/data3/train/mask/5006.jpg
#   inflating: DataSet/data3/train/mask/5007.jpg
#   inflating: DataSet/data3/train/mask/5008.jpg
#   inflating: DataSet/data3/train/mask/5009.jpg
#   inflating: DataSet/data3/train/mask/5010.jpg
#   inflating: DataSet/data3/train/mask/5011.jpg
#   inflating: DataSet/data3/train/mask/5012.jpg
#   inflating: DataSet/data3/train/mask/5013.jpg
#   inflating: DataSet/data3/train/mask/5014.jpg
#   inflating: DataSet/data3/train/mask/5015.jpg
#   inflating: DataSet/data3/train/mask/5016.jpg
#   inflating: DataSet/data3/train/mask/5017.jpg
#   inflating: DataSet/data3/train/mask/5018.jpg
#   inflating: DataSet/data3/train/mask/5019.jpg
#   inflating: DataSet/data3/train/mask/5020.jpg
#   inflating: DataSet/data3/train/mask/5021.jpg
#   inflating: DataSet/data3/train/mask/5022.jpg
#   inflating: DataSet/data3/train/mask/5023.jpg
#   inflating: DataSet/data3/train/mask/5024.jpg
#   inflating: DataSet/data3/train/mask/5025.jpg
#   inflating: DataSet/data3/train/mask/5026.jpg
#   inflating: DataSet/data3/train/mask/5027.jpg
#   inflating: DataSet/data3/train/mask/5028.jpg
#   inflating: DataSet/data3/train/mask/5029.jpg
#   inflating: DataSet/data3/train/mask/851.jpg
#   inflating: DataSet/data3/train/mask/852.jpg
#   inflating: DataSet/data3/train/mask/853.jpg
#   inflating: DataSet/data3/train/mask/854.jpg
#   inflating: DataSet/data3/train/mask/855.jpg
#   inflating: DataSet/data3/train/mask/856.jpg
#   inflating: DataSet/data3/train/mask/857.jpg
#   inflating: DataSet/data3/train/mask/858.jpg
#   inflating: DataSet/data3/train/mask/859.jpg
#   inflating: DataSet/data3/train/mask/860.jpg
#   inflating: DataSet/data3/train/mask/861.jpg
#   inflating: DataSet/data3/train/mask/862.jpg
#   inflating: DataSet/data3/train/mask/863.jpg
#   inflating: DataSet/data3/train/mask/864.jpg
#   inflating: DataSet/data3/train/mask/865.jpg
#   inflating: DataSet/data3/train/mask/866.jpg
#   inflating: DataSet/data3/train/mask/867.jpg
#   inflating: DataSet/data3/train/mask/868.jpg
#   inflating: DataSet/data3/train/mask/869.jpg
#   inflating: DataSet/data3/train/mask/870.jpg
#   inflating: DataSet/data3/train/mask/871.jpg
#   inflating: DataSet/data3/train/mask/872.jpg
#   inflating: DataSet/data3/train/mask/873.jpg
#   inflating: DataSet/data3/train/mask/874.jpg
#   inflating: DataSet/data3/train/mask/875.jpg
#   inflating: DataSet/data3/train/mask/876.jpg
#   inflating: DataSet/data3/train/mask/877.jpg
#   inflating: DataSet/data3/train/mask/878.jpg
#   inflating: DataSet/data3/train/mask/879.jpg
#   inflating: DataSet/data3/train/mask/880.jpg
#   inflating: DataSet/data3/train/mask/881.jpg
#   inflating: DataSet/data3/train/mask/882.jpg
#   inflating: DataSet/data3/train/mask/883.jpg
#   inflating: DataSet/data3/train/mask/884.jpg
#   inflating: DataSet/data3/train/mask/885.jpg
#   inflating: DataSet/data3/train/mask/886.jpg
#   inflating: DataSet/data3/train/mask/887.jpg
#   inflating: DataSet/data3/train/mask/888.jpg
#   inflating: DataSet/data3/train/mask/889.jpg
#   inflating: DataSet/data3/train/mask/890.jpg
#   inflating: DataSet/data3/train/mask/891.jpg
#   inflating: DataSet/data3/train/mask/892.jpg
#   inflating: DataSet/data3/train/mask/893.jpg
#   inflating: DataSet/data3/train/mask/894.jpg
#   inflating: DataSet/data3/train/mask/895.jpg
#   inflating: DataSet/data3/train/mask/896.jpg
#   inflating: DataSet/data3/train/mask/897.jpg
#   inflating: DataSet/data3/train/mask/898.jpg
#   inflating: DataSet/data3/train/mask/899.jpg
#   inflating: DataSet/data3/train/mask/900.jpg
#   inflating: DataSet/data3/train/mask/901.jpg
#   inflating: DataSet/data3/train/mask/902.jpg
#   inflating: DataSet/data3/train/mask/903.jpg
#   inflating: DataSet/data3/train/mask/904.jpg
#   inflating: DataSet/data3/train/mask/905.jpg
#   inflating: DataSet/data3/train/mask/906.jpg
#   inflating: DataSet/data3/train/mask/907.jpg
#   inflating: DataSet/data3/train/mask/908.jpg
#   inflating: DataSet/data3/train/mask/909.jpg
#   inflating: DataSet/data3/train/mask/910.jpg
#   inflating: DataSet/data3/train/mask/911.jpg
#   inflating: DataSet/data3/train/mask/912.jpg
#   inflating: DataSet/data3/train/mask/913.jpg
#   inflating: DataSet/data3/train/mask/914.jpg
#   inflating: DataSet/data3/train/mask/915.jpg
#   inflating: DataSet/data3/train/mask/916.jpg
#   inflating: DataSet/data3/train/mask/917.jpg
#   inflating: DataSet/data3/train/mask/918.jpg
#   inflating: DataSet/data3/train/mask/919.jpg
#   inflating: DataSet/data3/train/mask/920.jpg
#   inflating: DataSet/data3/train/mask/921.jpg
#   inflating: DataSet/data3/train/mask/922.jpg
#   inflating: DataSet/data3/train/mask/923.jpg
#   inflating: DataSet/data3/train/mask/924.jpg
#   inflating: DataSet/data3/train/mask/925.jpg
#   inflating: DataSet/data3/train/mask/926.jpg
#   inflating: DataSet/data3/train/mask/927.jpg
#   inflating: DataSet/data3/train/mask/928.jpg
#   inflating: DataSet/data3/train/mask/929.jpg
#   inflating: DataSet/data3/train/mask/930.jpg
#   inflating: DataSet/data3/train/mask/931.jpg
#   inflating: DataSet/data3/train/mask/932.jpg
#   inflating: DataSet/data3/train/mask/933.jpg
#   inflating: DataSet/data3/train/mask/934.jpg
#   inflating: DataSet/data3/train/mask/935.jpg
#   inflating: DataSet/data3/train/mask/936.jpg
#   inflating: DataSet/data3/train/mask/937.jpg
#   inflating: DataSet/data3/train/mask/938.jpg
#   inflating: DataSet/data3/train/mask/939.jpg
#   inflating: DataSet/data3/train/mask/940.jpg
#   inflating: DataSet/data3/train/mask/941.jpg
#   inflating: DataSet/data3/train/mask/942.jpg
#   inflating: DataSet/data3/train/mask/943.jpg
#   inflating: DataSet/data3/train/mask/944.jpg
#   inflating: DataSet/data3/train/mask/945.jpg
#   inflating: DataSet/data3/train/mask/946.jpg
#   inflating: DataSet/data3/train/mask/947.jpg
#   inflating: DataSet/data3/train/mask/948.jpg
#   inflating: DataSet/data3/train/mask/949.jpg
#   inflating: DataSet/data3/train/mask/950.jpg
#   inflating: DataSet/data3/train/mask/951.jpg
#   inflating: DataSet/data3/train/mask/952.jpg
#   inflating: DataSet/data3/train/mask/953.jpg
#   inflating: DataSet/data3/train/mask/954.jpg
#   inflating: DataSet/data3/train/mask/955.jpg
#   inflating: DataSet/data3/train/mask/956.jpg
#   inflating: DataSet/data3/train/mask/957.jpg
#   inflating: DataSet/data3/train/mask/958.jpg
#   inflating: DataSet/data3/train/mask/959.jpg
#   inflating: DataSet/data3/train/mask/960.jpg
#   inflating: DataSet/data3/train/mask/961.jpg
#   inflating: DataSet/data3/train/mask/962.jpg
#   inflating: DataSet/data3/train/mask/963.jpg
#   inflating: DataSet/data3/train/mask/964.jpg
#   inflating: DataSet/data3/train/mask/965.jpg
#   inflating: DataSet/data3/train/mask/966.jpg
#   inflating: DataSet/data3/train/mask/967.jpg
#   inflating: DataSet/data3/train/mask/968.jpg
#   inflating: DataSet/data3/train/mask/969.jpg
#   inflating: DataSet/data3/train/mask/970.jpg
#   inflating: DataSet/data3/train/mask/971.jpg
#   inflating: DataSet/data3/train/mask/972.jpg
#   inflating: DataSet/data3/train/mask/973.jpg
#   inflating: DataSet/data3/train/mask/974.jpg
#   inflating: DataSet/data3/train/mask/975.jpg
#   inflating: DataSet/data3/train/mask/976.jpg
#   inflating: DataSet/data3/train/mask/977.jpg
#   inflating: DataSet/data3/train/mask/978.jpg
#   inflating: DataSet/data3/train/mask/979.jpg
#   inflating: DataSet/data3/train/mask/980.jpg
#   inflating: DataSet/data3/train/mask/981.jpg
#   inflating: DataSet/data3/train/mask/982.jpg
#   inflating: DataSet/data3/train/mask/983.jpg
#   inflating: DataSet/data3/train/mask/984.jpg
#   inflating: DataSet/data3/train/mask/985.jpg
#   inflating: DataSet/data3/train/mask/986.jpg
#   inflating: DataSet/data3/train/mask/987.jpg
#   inflating: DataSet/data3/train/mask/988.jpg
#   inflating: DataSet/data3/train/mask/989.jpg
#   inflating: DataSet/data3/train/mask/990.jpg
#   inflating: DataSet/data3/train/mask/991.jpg
#   inflating: DataSet/data3/train/mask/992.jpg
#   inflating: DataSet/data3/train/mask/993.jpg
#   inflating: DataSet/data3/train/mask/994.jpg
#   inflating: DataSet/data3/train/mask/995.jpg
#   inflating: DataSet/data3/train/mask/996.jpg
#   inflating: DataSet/data3/train/mask/997.jpg
#   inflating: DataSet/data3/train/mask/998.jpg
#   inflating: DataSet/data3/train/mask/999.jpg
#   inflating: DataSet/data3/val/image/2000.jpg
#   inflating: DataSet/data3/val/image/2001.jpg
#   inflating: DataSet/data3/val/image/2002.jpg
#   inflating: DataSet/data3/val/image/2003.jpg
#   inflating: DataSet/data3/val/image/2004.jpg
#   inflating: DataSet/data3/val/image/2005.jpg
#   inflating: DataSet/data3/val/image/2006.jpg
#   inflating: DataSet/data3/val/image/2007.jpg
#   inflating: DataSet/data3/val/image/2008.jpg
#   inflating: DataSet/data3/val/image/2009.jpg
#   inflating: DataSet/data3/val/image/2010.jpg
#   inflating: DataSet/data3/val/image/2011.jpg
#   inflating: DataSet/data3/val/image/2012.jpg
#   inflating: DataSet/data3/val/image/2013.jpg
#   inflating: DataSet/data3/val/image/2014.jpg
#   inflating: DataSet/data3/val/image/2015.jpg
#   inflating: DataSet/data3/val/image/2016.jpg
#   inflating: DataSet/data3/val/image/2017.jpg
#   inflating: DataSet/data3/val/image/2018.jpg
#   inflating: DataSet/data3/val/image/2019.jpg
#   inflating: DataSet/data3/val/image/2020.jpg
#   inflating: DataSet/data3/val/image/2021.jpg
#   inflating: DataSet/data3/val/image/2022.jpg
#   inflating: DataSet/data3/val/image/2023.jpg
#   inflating: DataSet/data3/val/image/2024.jpg
#   inflating: DataSet/data3/val/image/2025.jpg
#   inflating: DataSet/data3/val/image/2026.jpg
#   inflating: DataSet/data3/val/image/2027.jpg
#   inflating: DataSet/data3/val/image/2028.jpg
#   inflating: DataSet/data3/val/image/2029.jpg
#   inflating: DataSet/data3/val/image/2030.jpg
#   inflating: DataSet/data3/val/image/2031.jpg
#   inflating: DataSet/data3/val/image/2032.jpg
#   inflating: DataSet/data3/val/image/2033.jpg
#   inflating: DataSet/data3/val/image/2034.jpg
#   inflating: DataSet/data3/val/image/2035.jpg
#   inflating: DataSet/data3/val/image/2036.jpg
#   inflating: DataSet/data3/val/image/2037.jpg
#   inflating: DataSet/data3/val/image/2038.jpg
#   inflating: DataSet/data3/val/image/2039.jpg
#   inflating: DataSet/data3/val/image/2040.jpg
#   inflating: DataSet/data3/val/image/2041.jpg
#   inflating: DataSet/data3/val/image/2042.jpg
#   inflating: DataSet/data3/val/image/2043.jpg
#   inflating: DataSet/data3/val/image/2044.jpg
#   inflating: DataSet/data3/val/image/2045.jpg
#   inflating: DataSet/data3/val/image/2046.jpg
#   inflating: DataSet/data3/val/image/2047.jpg
#   inflating: DataSet/data3/val/image/2048.jpg
#   inflating: DataSet/data3/val/image/2049.jpg
#   inflating: DataSet/data3/val/image/2050.jpg
#   inflating: DataSet/data3/val/image/2051.jpg
#   inflating: DataSet/data3/val/image/2052.jpg
#   inflating: DataSet/data3/val/image/2053.jpg
#   inflating: DataSet/data3/val/image/2054.jpg
#   inflating: DataSet/data3/val/image/2055.jpg
#   inflating: DataSet/data3/val/image/2056.jpg
#   inflating: DataSet/data3/val/image/2057.jpg
#   inflating: DataSet/data3/val/image/2058.jpg
#   inflating: DataSet/data3/val/image/2059.jpg
#   inflating: DataSet/data3/val/image/2060.jpg
#   inflating: DataSet/data3/val/image/2061.jpg
#   inflating: DataSet/data3/val/image/2062.jpg
#   inflating: DataSet/data3/val/image/2063.jpg
#   inflating: DataSet/data3/val/image/2064.jpg
#   inflating: DataSet/data3/val/image/2065.jpg
#   inflating: DataSet/data3/val/image/2066.jpg
#   inflating: DataSet/data3/val/image/2067.jpg
#   inflating: DataSet/data3/val/image/2068.jpg
#   inflating: DataSet/data3/val/image/2069.jpg
#   inflating: DataSet/data3/val/image/2070.jpg
#   inflating: DataSet/data3/val/image/2071.jpg
#   inflating: DataSet/data3/val/image/2072.jpg
#   inflating: DataSet/data3/val/image/2073.jpg
#   inflating: DataSet/data3/val/image/2074.jpg
#   inflating: DataSet/data3/val/image/2075.jpg
#   inflating: DataSet/data3/val/image/2076.jpg
#   inflating: DataSet/data3/val/image/2077.jpg
#   inflating: DataSet/data3/val/image/2078.jpg
#   inflating: DataSet/data3/val/image/2079.jpg
#   inflating: DataSet/data3/val/image/2080.jpg
#   inflating: DataSet/data3/val/image/2081.jpg
#   inflating: DataSet/data3/val/image/2082.jpg
#   inflating: DataSet/data3/val/image/2083.jpg
#   inflating: DataSet/data3/val/image/2084.jpg
#   inflating: DataSet/data3/val/image/2085.jpg
#   inflating: DataSet/data3/val/image/2086.jpg
#   inflating: DataSet/data3/val/image/2087.jpg
#   inflating: DataSet/data3/val/image/2088.jpg
#   inflating: DataSet/data3/val/image/2089.jpg
#   inflating: DataSet/data3/val/image/2090.jpg
#   inflating: DataSet/data3/val/image/2091.jpg
#   inflating: DataSet/data3/val/image/2092.jpg
#   inflating: DataSet/data3/val/image/2093.jpg
#   inflating: DataSet/data3/val/image/2094.jpg
#   inflating: DataSet/data3/val/image/2095.jpg
#   inflating: DataSet/data3/val/image/2096.jpg
#   inflating: DataSet/data3/val/image/2097.jpg
#   inflating: DataSet/data3/val/image/2098.jpg
#   inflating: DataSet/data3/val/image/2099.jpg
#   inflating: DataSet/data3/val/image/2100.jpg
#   inflating: DataSet/data3/val/image/2101.jpg
#   inflating: DataSet/data3/val/image/2102.jpg
#   inflating: DataSet/data3/val/image/2103.jpg
#   inflating: DataSet/data3/val/image/2104.jpg
#   inflating: DataSet/data3/val/image/2105.jpg
#   inflating: DataSet/data3/val/image/2106.jpg
#   inflating: DataSet/data3/val/image/2107.jpg
#   inflating: DataSet/data3/val/image/2108.jpg
#   inflating: DataSet/data3/val/image/2109.jpg
#   inflating: DataSet/data3/val/image/2110.jpg
#   inflating: DataSet/data3/val/image/2111.jpg
#   inflating: DataSet/data3/val/image/2112.jpg
#   inflating: DataSet/data3/val/image/2113.jpg
#   inflating: DataSet/data3/val/image/2114.jpg
#   inflating: DataSet/data3/val/image/2115.jpg
#   inflating: DataSet/data3/val/image/2116.jpg
#   inflating: DataSet/data3/val/image/2117.jpg
#   inflating: DataSet/data3/val/image/2118.jpg
#   inflating: DataSet/data3/val/image/2119.jpg
#   inflating: DataSet/data3/val/image/2120.jpg
#   inflating: DataSet/data3/val/image/2121.jpg
#   inflating: DataSet/data3/val/image/2122.jpg
#   inflating: DataSet/data3/val/image/2123.jpg
#   inflating: DataSet/data3/val/image/2124.jpg
#   inflating: DataSet/data3/val/image/2125.jpg
#   inflating: DataSet/data3/val/image/2126.jpg
#   inflating: DataSet/data3/val/image/2127.jpg
#   inflating: DataSet/data3/val/image/2128.jpg
#   inflating: DataSet/data3/val/image/2129.jpg
#   inflating: DataSet/data3/val/image/2130.jpg
#   inflating: DataSet/data3/val/image/2131.jpg
#   inflating: DataSet/data3/val/image/2132.jpg
#   inflating: DataSet/data3/val/image/2133.jpg
#   inflating: DataSet/data3/val/image/2134.jpg
#   inflating: DataSet/data3/val/image/2135.jpg
#   inflating: DataSet/data3/val/image/2136.jpg
#   inflating: DataSet/data3/val/image/2137.jpg
#   inflating: DataSet/data3/val/image/2138.jpg
#   inflating: DataSet/data3/val/image/2139.jpg
#   inflating: DataSet/data3/val/image/2140.jpg
#   inflating: DataSet/data3/val/image/2141.jpg
#   inflating: DataSet/data3/val/image/2142.jpg
#   inflating: DataSet/data3/val/image/2143.jpg
#   inflating: DataSet/data3/val/image/2144.jpg
#   inflating: DataSet/data3/val/image/2145.jpg
#   inflating: DataSet/data3/val/image/2146.jpg
#   inflating: DataSet/data3/val/image/2147.jpg
#   inflating: DataSet/data3/val/image/2148.jpg
#   inflating: DataSet/data3/val/image/2149.jpg
#   inflating: DataSet/data3/val/image/2150.jpg
#   inflating: DataSet/data3/val/image/2151.jpg
#   inflating: DataSet/data3/val/image/2152.jpg
#   inflating: DataSet/data3/val/image/2153.jpg
#   inflating: DataSet/data3/val/image/2154.jpg
#   inflating: DataSet/data3/val/image/2155.jpg
#   inflating: DataSet/data3/val/image/2156.jpg
#   inflating: DataSet/data3/val/image/2157.jpg
#   inflating: DataSet/data3/val/image/2158.jpg
#   inflating: DataSet/data3/val/image/2159.jpg
#   inflating: DataSet/data3/val/image/2160.jpg
#   inflating: DataSet/data3/val/image/2161.jpg
#   inflating: DataSet/data3/val/image/2162.jpg
#   inflating: DataSet/data3/val/image/2163.jpg
#   inflating: DataSet/data3/val/image/2164.jpg
#   inflating: DataSet/data3/val/image/2165.jpg
#   inflating: DataSet/data3/val/image/2166.jpg
#   inflating: DataSet/data3/val/image/2167.jpg
#   inflating: DataSet/data3/val/image/2168.jpg
#   inflating: DataSet/data3/val/image/2169.jpg
#   inflating: DataSet/data3/val/image/2170.jpg
#   inflating: DataSet/data3/val/image/2171.jpg
#   inflating: DataSet/data3/val/image/2172.jpg
#   inflating: DataSet/data3/val/image/2173.jpg
#   inflating: DataSet/data3/val/image/2174.jpg
#   inflating: DataSet/data3/val/image/2175.jpg
#   inflating: DataSet/data3/val/image/2176.jpg
#   inflating: DataSet/data3/val/image/2177.jpg
#   inflating: DataSet/data3/val/image/2178.jpg
#   inflating: DataSet/data3/val/image/2179.jpg
#   inflating: DataSet/data3/val/image/2180.jpg
#   inflating: DataSet/data3/val/image/2181.jpg
#   inflating: DataSet/data3/val/image/2182.jpg
#   inflating: DataSet/data3/val/image/2183.jpg
#   inflating: DataSet/data3/val/image/2184.jpg
#   inflating: DataSet/data3/val/image/2185.jpg
#   inflating: DataSet/data3/val/image/2186.jpg
#   inflating: DataSet/data3/val/image/2187.jpg
#   inflating: DataSet/data3/val/image/2188.jpg
#   inflating: DataSet/data3/val/image/2189.jpg
#   inflating: DataSet/data3/val/image/2190.jpg
#   inflating: DataSet/data3/val/image/2191.jpg
#   inflating: DataSet/data3/val/image/2192.jpg
#   inflating: DataSet/data3/val/image/2193.jpg
#   inflating: DataSet/data3/val/image/2194.jpg
#   inflating: DataSet/data3/val/image/2195.jpg
#   inflating: DataSet/data3/val/image/2196.jpg
#   inflating: DataSet/data3/val/image/2197.jpg
#   inflating: DataSet/data3/val/image/2198.jpg
#   inflating: DataSet/data3/val/image/2199.jpg
#   inflating: DataSet/data3/val/image/2200.jpg
#   inflating: DataSet/data3/val/image/2201.jpg
#   inflating: DataSet/data3/val/image/2202.jpg
#   inflating: DataSet/data3/val/image/2203.jpg
#   inflating: DataSet/data3/val/image/2204.jpg
#   inflating: DataSet/data3/val/image/2205.jpg
#   inflating: DataSet/data3/val/image/2206.jpg
#   inflating: DataSet/data3/val/image/2207.jpg
#   inflating: DataSet/data3/val/image/2208.jpg
#   inflating: DataSet/data3/val/image/2209.jpg
#   inflating: DataSet/data3/val/image/2210.jpg
#   inflating: DataSet/data3/val/image/2211.jpg
#   inflating: DataSet/data3/val/image/2212.jpg
#   inflating: DataSet/data3/val/image/2213.jpg
#   inflating: DataSet/data3/val/image/2214.jpg
#   inflating: DataSet/data3/val/image/2215.jpg
#   inflating: DataSet/data3/val/image/2216.jpg
#   inflating: DataSet/data3/val/image/2217.jpg
#   inflating: DataSet/data3/val/image/2218.jpg
#   inflating: DataSet/data3/val/image/2219.jpg
#   inflating: DataSet/data3/val/image/2220.jpg
#   inflating: DataSet/data3/val/image/2221.jpg
#   inflating: DataSet/data3/val/image/2222.jpg
#   inflating: DataSet/data3/val/image/2223.jpg
#   inflating: DataSet/data3/val/image/2224.jpg
#   inflating: DataSet/data3/val/image/2225.jpg
#   inflating: DataSet/data3/val/image/2226.jpg
#   inflating: DataSet/data3/val/image/2227.jpg
#   inflating: DataSet/data3/val/image/2228.jpg
#   inflating: DataSet/data3/val/image/2229.jpg
#   inflating: DataSet/data3/val/image/2230.jpg
#   inflating: DataSet/data3/val/image/2231.jpg
#   inflating: DataSet/data3/val/image/2232.jpg
#   inflating: DataSet/data3/val/image/2233.jpg
#   inflating: DataSet/data3/val/image/2234.jpg
#   inflating: DataSet/data3/val/image/2235.jpg
#   inflating: DataSet/data3/val/image/2236.jpg
#   inflating: DataSet/data3/val/image/2237.jpg
#   inflating: DataSet/data3/val/image/2238.jpg
#   inflating: DataSet/data3/val/image/2239.jpg
#   inflating: DataSet/data3/val/image/2240.jpg
#   inflating: DataSet/data3/val/image/2241.jpg
#   inflating: DataSet/data3/val/image/2242.jpg
#   inflating: DataSet/data3/val/image/2243.jpg
#   inflating: DataSet/data3/val/image/2244.jpg
#   inflating: DataSet/data3/val/image/2245.jpg
#   inflating: DataSet/data3/val/image/2246.jpg
#   inflating: DataSet/data3/val/image/2247.jpg
#   inflating: DataSet/data3/val/image/2248.jpg
#   inflating: DataSet/data3/val/image/2249.jpg
#   inflating: DataSet/data3/val/image/2250.jpg
#   inflating: DataSet/data3/val/image/2251.jpg
#   inflating: DataSet/data3/val/image/2252.jpg
#   inflating: DataSet/data3/val/image/2253.jpg
#   inflating: DataSet/data3/val/image/2254.jpg
#   inflating: DataSet/data3/val/image/2255.jpg
#   inflating: DataSet/data3/val/image/2256.jpg
#   inflating: DataSet/data3/val/image/2257.jpg
#   inflating: DataSet/data3/val/image/2258.jpg
#   inflating: DataSet/data3/val/image/2259.jpg
#   inflating: DataSet/data3/val/image/2260.jpg
#   inflating: DataSet/data3/val/image/2261.jpg
#   inflating: DataSet/data3/val/image/2262.jpg
#   inflating: DataSet/data3/val/image/2263.jpg
#   inflating: DataSet/data3/val/image/2264.jpg
#   inflating: DataSet/data3/val/image/2265.jpg
#   inflating: DataSet/data3/val/image/2266.jpg
#   inflating: DataSet/data3/val/image/2267.jpg
#   inflating: DataSet/data3/val/image/2268.jpg
#   inflating: DataSet/data3/val/image/2269.jpg
#   inflating: DataSet/data3/val/image/2270.jpg
#   inflating: DataSet/data3/val/image/2271.jpg
#   inflating: DataSet/data3/val/image/2272.jpg
#   inflating: DataSet/data3/val/image/2273.jpg
#   inflating: DataSet/data3/val/image/2274.jpg
#   inflating: DataSet/data3/val/image/2275.jpg
#   inflating: DataSet/data3/val/image/2276.jpg
#   inflating: DataSet/data3/val/image/2277.jpg
#   inflating: DataSet/data3/val/image/2278.jpg
#   inflating: DataSet/data3/val/image/2279.jpg
#   inflating: DataSet/data3/val/image/2280.jpg
#   inflating: DataSet/data3/val/image/2281.jpg
#   inflating: DataSet/data3/val/image/2282.jpg
#   inflating: DataSet/data3/val/image/2283.jpg
#   inflating: DataSet/data3/val/image/2284.jpg
#   inflating: DataSet/data3/val/image/2285.jpg
#   inflating: DataSet/data3/val/image/2286.jpg
#   inflating: DataSet/data3/val/image/2287.jpg
#   inflating: DataSet/data3/val/image/2288.jpg
#   inflating: DataSet/data3/val/image/2289.jpg
#   inflating: DataSet/data3/val/image/2290.jpg
#   inflating: DataSet/data3/val/image/2291.jpg
#   inflating: DataSet/data3/val/image/2292.jpg
#   inflating: DataSet/data3/val/image/2293.jpg
#   inflating: DataSet/data3/val/image/2294.jpg
#   inflating: DataSet/data3/val/image/2295.jpg
#   inflating: DataSet/data3/val/image/2296.jpg
#   inflating: DataSet/data3/val/image/2297.jpg
#   inflating: DataSet/data3/val/image/2298.jpg
#   inflating: DataSet/data3/val/image/2299.jpg
#   inflating: DataSet/data3/val/image/2300.jpg
#   inflating: DataSet/data3/val/image/2301.jpg
#   inflating: DataSet/data3/val/image/2302.jpg
#   inflating: DataSet/data3/val/image/2303.jpg
#   inflating: DataSet/data3/val/image/2304.jpg
#   inflating: DataSet/data3/val/image/2305.jpg
#   inflating: DataSet/data3/val/image/2306.jpg
#   inflating: DataSet/data3/val/image/2307.jpg
#   inflating: DataSet/data3/val/image/2308.jpg
#   inflating: DataSet/data3/val/image/2309.jpg
#   inflating: DataSet/data3/val/image/2310.jpg
#   inflating: DataSet/data3/val/image/2311.jpg
#   inflating: DataSet/data3/val/image/2312.jpg
#   inflating: DataSet/data3/val/image/2313.jpg
#   inflating: DataSet/data3/val/image/2314.jpg
#   inflating: DataSet/data3/val/image/2315.jpg
#   inflating: DataSet/data3/val/image/2316.jpg
#   inflating: DataSet/data3/val/image/2317.jpg
#   inflating: DataSet/data3/val/image/2318.jpg
#   inflating: DataSet/data3/val/image/2319.jpg
#   inflating: DataSet/data3/val/image/2320.jpg
#   inflating: DataSet/data3/val/image/2321.jpg
#   inflating: DataSet/data3/val/image/2322.jpg
#   inflating: DataSet/data3/val/image/2323.jpg
#   inflating: DataSet/data3/val/image/2324.jpg
#   inflating: DataSet/data3/val/image/2325.jpg
#   inflating: DataSet/data3/val/image/2326.jpg
#   inflating: DataSet/data3/val/image/2327.jpg
#   inflating: DataSet/data3/val/image/2328.jpg
#   inflating: DataSet/data3/val/image/2329.jpg
#   inflating: DataSet/data3/val/image/2330.jpg
#   inflating: DataSet/data3/val/image/2331.jpg
#   inflating: DataSet/data3/val/image/2332.jpg
#   inflating: DataSet/data3/val/image/2333.jpg
#   inflating: DataSet/data3/val/image/2334.jpg
#   inflating: DataSet/data3/val/image/2335.jpg
#   inflating: DataSet/data3/val/image/2336.jpg
#   inflating: DataSet/data3/val/image/2337.jpg
#   inflating: DataSet/data3/val/image/2338.jpg
#   inflating: DataSet/data3/val/image/2339.jpg
#   inflating: DataSet/data3/val/image/2340.jpg
#   inflating: DataSet/data3/val/image/2341.jpg
#   inflating: DataSet/data3/val/image/2342.jpg
#   inflating: DataSet/data3/val/image/2343.jpg
#   inflating: DataSet/data3/val/image/2344.jpg
#   inflating: DataSet/data3/val/image/2345.jpg
#   inflating: DataSet/data3/val/image/2346.jpg
#   inflating: DataSet/data3/val/image/2347.jpg
#   inflating: DataSet/data3/val/image/2348.jpg
#   inflating: DataSet/data3/val/image/2349.jpg
#   inflating: DataSet/data3/val/image/2350.jpg
#   inflating: DataSet/data3/val/image/2351.jpg
#   inflating: DataSet/data3/val/image/2352.jpg
#   inflating: DataSet/data3/val/image/2353.jpg
#   inflating: DataSet/data3/val/image/2354.jpg
#   inflating: DataSet/data3/val/image/2355.jpg
#   inflating: DataSet/data3/val/image/2356.jpg
#   inflating: DataSet/data3/val/image/2357.jpg
#   inflating: DataSet/data3/val/image/2358.jpg
#   inflating: DataSet/data3/val/image/2359.jpg
#   inflating: DataSet/data3/val/image/2360.jpg
#   inflating: DataSet/data3/val/image/2361.jpg
#   inflating: DataSet/data3/val/image/2362.jpg
#   inflating: DataSet/data3/val/image/2363.jpg
#   inflating: DataSet/data3/val/image/2364.jpg
#   inflating: DataSet/data3/val/image/2365.jpg
#   inflating: DataSet/data3/val/image/2366.jpg
#   inflating: DataSet/data3/val/image/2367.jpg
#   inflating: DataSet/data3/val/image/2368.jpg
#   inflating: DataSet/data3/val/image/2369.jpg
#   inflating: DataSet/data3/val/image/2370.jpg
#   inflating: DataSet/data3/val/image/2371.jpg
#   inflating: DataSet/data3/val/image/2372.jpg
#   inflating: DataSet/data3/val/image/2373.jpg
#   inflating: DataSet/data3/val/image/2374.jpg
#   inflating: DataSet/data3/val/image/2375.jpg
#   inflating: DataSet/data3/val/image/2376.jpg
#   inflating: DataSet/data3/val/image/2377.jpg
#   inflating: DataSet/data3/val/image/2378.jpg
#   inflating: DataSet/data3/val/image/2379.jpg
#   inflating: DataSet/data3/val/image/2380.jpg
#   inflating: DataSet/data3/val/image/2381.jpg
#   inflating: DataSet/data3/val/image/2382.jpg
#   inflating: DataSet/data3/val/image/2383.jpg
#   inflating: DataSet/data3/val/image/2384.jpg
#   inflating: DataSet/data3/val/image/2385.jpg
#   inflating: DataSet/data3/val/image/2386.jpg
#   inflating: DataSet/data3/val/image/2387.jpg
#   inflating: DataSet/data3/val/image/2388.jpg
#   inflating: DataSet/data3/val/image/2389.jpg
#   inflating: DataSet/data3/val/image/2390.jpg
#   inflating: DataSet/data3/val/image/2391.jpg
#   inflating: DataSet/data3/val/image/2392.jpg
#   inflating: DataSet/data3/val/image/2393.jpg
#   inflating: DataSet/data3/val/image/2394.jpg
#   inflating: DataSet/data3/val/image/2395.jpg
#   inflating: DataSet/data3/val/image/2396.jpg
#   inflating: DataSet/data3/val/image/2397.jpg
#   inflating: DataSet/data3/val/image/2398.jpg
#   inflating: DataSet/data3/val/image/2399.jpg
#   inflating: DataSet/data3/val/image/2400.jpg
#   inflating: DataSet/data3/val/image/2401.jpg
#   inflating: DataSet/data3/val/image/2402.jpg
#   inflating: DataSet/data3/val/image/2403.jpg
#   inflating: DataSet/data3/val/image/2404.jpg
#   inflating: DataSet/data3/val/image/2405.jpg
#   inflating: DataSet/data3/val/image/2406.jpg
#   inflating: DataSet/data3/val/image/2407.jpg
#   inflating: DataSet/data3/val/image/2408.jpg
#   inflating: DataSet/data3/val/image/2409.jpg
#   inflating: DataSet/data3/val/image/2410.jpg
#   inflating: DataSet/data3/val/image/2411.jpg
#   inflating: DataSet/data3/val/image/2412.jpg
#   inflating: DataSet/data3/val/image/2413.jpg
#   inflating: DataSet/data3/val/image/2414.jpg
# ...
#   inflating: DataSet/data4/train/mask/861.jpg
#   inflating: DataSet/data4/train/mask/862.jpg
#   inflating: DataSet/data4/train/mask/863.jpg
#   inflating: DataSet/data4/train/mask/864.jpg
#   inflating: DataSet/data4/train/mask/865.jpg
#   inflating: DataSet/data4/train/mask/866.jpg
#   inflating: DataSet/data4/train/mask/867.jpg
#   inflating: DataSet/data4/train/mask/868.jpg
#   inflating: DataSet/data4/train/mask/869.jpg
#   inflating: DataSet/data4/train/mask/870.jpg
#   inflating: DataSet/data4/train/mask/871.jpg
#   inflating: DataSet/data4/train/mask/872.jpg
#   inflating: DataSet/data4/train/mask/873.jpg
#   inflating: DataSet/data4/train/mask/874.jpg
#   inflating: DataSet/data4/train/mask/875.jpg
#   inflating: DataSet/data4/train/mask/876.jpg
#   inflating: DataSet/data4/train/mask/877.jpg
#   inflating: DataSet/data4/train/mask/878.jpg
#   inflating: DataSet/data4/train/mask/879.jpg
#   inflating: DataSet/data4/train/mask/880.jpg
#   inflating: DataSet/data4/train/mask/881.jpg
#   inflating: DataSet/data4/train/mask/882.jpg
#   inflating: DataSet/data4/train/mask/883.jpg
#   inflating: DataSet/data4/train/mask/884.jpg
#   inflating: DataSet/data4/train/mask/885.jpg
#   inflating: DataSet/data4/train/mask/886.jpg
#   inflating: DataSet/data4/train/mask/887.jpg
#   inflating: DataSet/data4/train/mask/888.jpg
#   inflating: DataSet/data4/train/mask/889.jpg
#   inflating: DataSet/data4/train/mask/890.jpg
#   inflating: DataSet/data4/train/mask/891.jpg
#   inflating: DataSet/data4/train/mask/892.jpg
#   inflating: DataSet/data4/train/mask/893.jpg
#   inflating: DataSet/data4/train/mask/894.jpg
#   inflating: DataSet/data4/train/mask/895.jpg
#   inflating: DataSet/data4/train/mask/896.jpg
#   inflating: DataSet/data4/train/mask/897.jpg
#   inflating: DataSet/data4/train/mask/898.jpg
#   inflating: DataSet/data4/train/mask/899.jpg
#   inflating: DataSet/data4/train/mask/900.jpg
#   inflating: DataSet/data4/train/mask/901.jpg
#   inflating: DataSet/data4/train/mask/902.jpg
#   inflating: DataSet/data4/train/mask/903.jpg
#   inflating: DataSet/data4/train/mask/904.jpg
#   inflating: DataSet/data4/train/mask/905.jpg
#   inflating: DataSet/data4/train/mask/906.jpg
#   inflating: DataSet/data4/train/mask/907.jpg
#   inflating: DataSet/data4/train/mask/908.jpg
#   inflating: DataSet/data4/train/mask/909.jpg
#   inflating: DataSet/data4/train/mask/910.jpg
#   inflating: DataSet/data4/train/mask/911.jpg
#   inflating: DataSet/data4/train/mask/912.jpg
#   inflating: DataSet/data4/train/mask/913.jpg
#   inflating: DataSet/data4/train/mask/914.jpg
#   inflating: DataSet/data4/train/mask/915.jpg
#   inflating: DataSet/data4/train/mask/916.jpg
#   inflating: DataSet/data4/train/mask/917.jpg
#   inflating: DataSet/data4/train/mask/918.jpg
#   inflating: DataSet/data4/train/mask/919.jpg
#   inflating: DataSet/data4/train/mask/920.jpg
#   inflating: DataSet/data4/train/mask/921.jpg
#   inflating: DataSet/data4/train/mask/922.jpg
#   inflating: DataSet/data4/train/mask/923.jpg
#   inflating: DataSet/data4/train/mask/924.jpg
#   inflating: DataSet/data4/train/mask/925.jpg
#   inflating: DataSet/data4/train/mask/926.jpg
#   inflating: DataSet/data4/train/mask/927.jpg
#   inflating: DataSet/data4/train/mask/928.jpg
#   inflating: DataSet/data4/train/mask/929.jpg
#   inflating: DataSet/data4/train/mask/930.jpg
#   inflating: DataSet/data4/train/mask/931.jpg
#   inflating: DataSet/data4/train/mask/932.jpg
#   inflating: DataSet/data4/train/mask/933.jpg
#   inflating: DataSet/data4/train/mask/934.jpg
#   inflating: DataSet/data4/train/mask/935.jpg
#   inflating: DataSet/data4/train/mask/936.jpg
#   inflating: DataSet/data4/train/mask/937.jpg
#   inflating: DataSet/data4/train/mask/938.jpg
#   inflating: DataSet/data4/train/mask/939.jpg
#   inflating: DataSet/data4/train/mask/940.jpg
#   inflating: DataSet/data4/train/mask/941.jpg
#   inflating: DataSet/data4/train/mask/942.jpg
#   inflating: DataSet/data4/train/mask/943.jpg
#   inflating: DataSet/data4/train/mask/944.jpg
#   inflating: DataSet/data4/train/mask/945.jpg
#   inflating: DataSet/data4/train/mask/946.jpg
#   inflating: DataSet/data4/train/mask/947.jpg
#   inflating: DataSet/data4/train/mask/948.jpg
#   inflating: DataSet/data4/train/mask/949.jpg
#   inflating: DataSet/data4/train/mask/950.jpg
#   inflating: DataSet/data4/train/mask/951.jpg
#   inflating: DataSet/data4/train/mask/952.jpg
#   inflating: DataSet/data4/train/mask/953.jpg
#   inflating: DataSet/data4/train/mask/954.jpg
#   inflating: DataSet/data4/train/mask/955.jpg
#   inflating: DataSet/data4/train/mask/956.jpg
#   inflating: DataSet/data4/train/mask/957.jpg
#   inflating: DataSet/data4/train/mask/958.jpg
#   inflating: DataSet/data4/train/mask/959.jpg
#   inflating: DataSet/data4/train/mask/960.jpg
#   inflating: DataSet/data4/train/mask/961.jpg
#   inflating: DataSet/data4/train/mask/962.jpg
#   inflating: DataSet/data4/train/mask/963.jpg
#   inflating: DataSet/data4/train/mask/964.jpg
#   inflating: DataSet/data4/train/mask/965.jpg
#   inflating: DataSet/data4/train/mask/966.jpg
#   inflating: DataSet/data4/train/mask/967.jpg
#   inflating: DataSet/data4/train/mask/968.jpg
#   inflating: DataSet/data4/train/mask/969.jpg
#   inflating: DataSet/data4/train/mask/970.jpg
#   inflating: DataSet/data4/train/mask/971.jpg
#   inflating: DataSet/data4/train/mask/972.jpg
#   inflating: DataSet/data4/train/mask/973.jpg
#   inflating: DataSet/data4/train/mask/974.jpg
#   inflating: DataSet/data4/train/mask/975.jpg
#   inflating: DataSet/data4/train/mask/976.jpg
#   inflating: DataSet/data4/train/mask/977.jpg
#   inflating: DataSet/data4/train/mask/978.jpg
#   inflating: DataSet/data4/train/mask/979.jpg
#   inflating: DataSet/data4/train/mask/980.jpg
#   inflating: DataSet/data4/train/mask/981.jpg
#   inflating: DataSet/data4/train/mask/982.jpg
#   inflating: DataSet/data4/train/mask/983.jpg
#   inflating: DataSet/data4/train/mask/984.jpg
#   inflating: DataSet/data4/train/mask/985.jpg
#   inflating: DataSet/data4/train/mask/986.jpg
#   inflating: DataSet/data4/train/mask/987.jpg
#   inflating: DataSet/data4/train/mask/988.jpg
#   inflating: DataSet/data4/train/mask/989.jpg
#   inflating: DataSet/data4/train/mask/990.jpg
#   inflating: DataSet/data4/train/mask/991.jpg
#   inflating: DataSet/data4/train/mask/992.jpg
#   inflating: DataSet/data4/train/mask/993.jpg
#   inflating: DataSet/data4/train/mask/994.jpg
#   inflating: DataSet/data4/train/mask/995.jpg
#   inflating: DataSet/data4/train/mask/996.jpg
#   inflating: DataSet/data4/train/mask/997.jpg
#   inflating: DataSet/data4/train/mask/998.jpg
#   inflating: DataSet/data4/train/mask/999.jpg
#   inflating: DataSet/data4/val/image/600.jpg
#   inflating: DataSet/data4/val/image/601.jpg
#   inflating: DataSet/data4/val/image/602.jpg
#   inflating: DataSet/data4/val/image/603.jpg
#   inflating: DataSet/data4/val/image/604.jpg
#   inflating: DataSet/data4/val/image/605.jpg
#   inflating: DataSet/data4/val/image/606.jpg
#   inflating: DataSet/data4/val/image/607.jpg
#   inflating: DataSet/data4/val/image/608.jpg
#   inflating: DataSet/data4/val/image/609.jpg
#   inflating: DataSet/data4/val/image/610.jpg
#   inflating: DataSet/data4/val/image/611.jpg
#   inflating: DataSet/data4/val/image/612.jpg
#   inflating: DataSet/data4/val/image/613.jpg
#   inflating: DataSet/data4/val/image/614.jpg
#   inflating: DataSet/data4/val/image/615.jpg
#   inflating: DataSet/data4/val/image/616.jpg
#   inflating: DataSet/data4/val/image/617.jpg
#   inflating: DataSet/data4/val/image/618.jpg
#   inflating: DataSet/data4/val/image/619.jpg
#   inflating: DataSet/data4/val/image/620.jpg
#   inflating: DataSet/data4/val/image/621.jpg
#   inflating: DataSet/data4/val/image/622.jpg
#   inflating: DataSet/data4/val/image/623.jpg
#   inflating: DataSet/data4/val/image/624.jpg
#   inflating: DataSet/data4/val/image/625.jpg
#   inflating: DataSet/data4/val/image/626.jpg
#   inflating: DataSet/data4/val/image/627.jpg
#   inflating: DataSet/data4/val/image/628.jpg
#   inflating: DataSet/data4/val/image/629.jpg
#   inflating: DataSet/data4/val/image/630.jpg
#   inflating: DataSet/data4/val/image/631.jpg
#   inflating: DataSet/data4/val/image/632.jpg
#   inflating: DataSet/data4/val/image/633.jpg
#   inflating: DataSet/data4/val/image/634.jpg
#   inflating: DataSet/data4/val/image/635.jpg
#   inflating: DataSet/data4/val/image/636.jpg
#   inflating: DataSet/data4/val/image/637.jpg
#   inflating: DataSet/data4/val/image/638.jpg
#   inflating: DataSet/data4/val/image/639.jpg
#   inflating: DataSet/data4/val/image/640.jpg
#   inflating: DataSet/data4/val/image/641.jpg
#   inflating: DataSet/data4/val/image/642.jpg
#   inflating: DataSet/data4/val/image/643.jpg
#   inflating: DataSet/data4/val/image/644.jpg
#   inflating: DataSet/data4/val/image/645.jpg
#   inflating: DataSet/data4/val/image/646.jpg
#   inflating: DataSet/data4/val/image/647.jpg
#   inflating: DataSet/data4/val/image/648.jpg
#   inflating: DataSet/data4/val/image/649.jpg
#   inflating: DataSet/data4/val/image/650.jpg
#   inflating: DataSet/data4/val/image/651.jpg
#   inflating: DataSet/data4/val/image/652.jpg
#   inflating: DataSet/data4/val/image/653.jpg
#   inflating: DataSet/data4/val/image/654.jpg
#   inflating: DataSet/data4/val/image/655.jpg
#   inflating: DataSet/data4/val/image/656.jpg
#   inflating: DataSet/data4/val/image/657.jpg
#   inflating: DataSet/data4/val/image/658.jpg
#   inflating: DataSet/data4/val/image/659.jpg
#   inflating: DataSet/data4/val/image/660.jpg
#   inflating: DataSet/data4/val/image/661.jpg
#   inflating: DataSet/data4/val/image/662.jpg
#   inflating: DataSet/data4/val/image/663.jpg
#   inflating: DataSet/data4/val/image/664.jpg
#   inflating: DataSet/data4/val/image/665.jpg
#   inflating: DataSet/data4/val/image/666.jpg
#   inflating: DataSet/data4/val/image/667.jpg
#   inflating: DataSet/data4/val/image/668.jpg
#   inflating: DataSet/data4/val/image/669.jpg
#   inflating: DataSet/data4/val/image/670.jpg
#   inflating: DataSet/data4/val/image/671.jpg
#   inflating: DataSet/data4/val/image/672.jpg
#   inflating: DataSet/data4/val/image/673.jpg
#   inflating: DataSet/data4/val/image/674.jpg
#   inflating: DataSet/data4/val/image/675.jpg
#   inflating: DataSet/data4/val/image/676.jpg
#   inflating: DataSet/data4/val/image/677.jpg
#   inflating: DataSet/data4/val/image/678.jpg
#   inflating: DataSet/data4/val/image/679.jpg
#   inflating: DataSet/data4/val/image/680.jpg
#   inflating: DataSet/data4/val/image/681.jpg
#   inflating: DataSet/data4/val/image/682.jpg
#   inflating: DataSet/data4/val/image/683.jpg
#   inflating: DataSet/data4/val/image/684.jpg
#   inflating: DataSet/data4/val/image/685.jpg
#   inflating: DataSet/data4/val/image/686.jpg
#   inflating: DataSet/data4/val/image/687.jpg
#   inflating: DataSet/data4/val/image/688.jpg
#   inflating: DataSet/data4/val/image/689.jpg
#   inflating: DataSet/data4/val/image/690.jpg
#   inflating: DataSet/data4/val/image/691.jpg
#   inflating: DataSet/data4/val/image/692.jpg
#   inflating: DataSet/data4/val/image/693.jpg
#   inflating: DataSet/data4/val/image/694.jpg
#   inflating: DataSet/data4/val/image/695.jpg
#   inflating: DataSet/data4/val/image/696.jpg
#   inflating: DataSet/data4/val/image/697.jpg
#   inflating: DataSet/data4/val/image/698.jpg
#   inflating: DataSet/data4/val/image/699.jpg
#   inflating: DataSet/data4/val/mask/600.jpg
#   inflating: DataSet/data4/val/mask/601.jpg
#   inflating: DataSet/data4/val/mask/602.jpg
#   inflating: DataSet/data4/val/mask/603.jpg
#   inflating: DataSet/data4/val/mask/604.jpg
#   inflating: DataSet/data4/val/mask/605.jpg
#   inflating: DataSet/data4/val/mask/606.jpg
#   inflating: DataSet/data4/val/mask/607.jpg
#   inflating: DataSet/data4/val/mask/608.jpg
#   inflating: DataSet/data4/val/mask/609.jpg
#   inflating: DataSet/data4/val/mask/610.jpg
#   inflating: DataSet/data4/val/mask/611.jpg
#   inflating: DataSet/data4/val/mask/612.jpg
#   inflating: DataSet/data4/val/mask/613.jpg
#   inflating: DataSet/data4/val/mask/614.jpg
#   inflating: DataSet/data4/val/mask/615.jpg
#   inflating: DataSet/data4/val/mask/616.jpg
#   inflating: DataSet/data4/val/mask/617.jpg
#   inflating: DataSet/data4/val/mask/618.jpg
#   inflating: DataSet/data4/val/mask/619.jpg
#   inflating: DataSet/data4/val/mask/620.jpg
#   inflating: DataSet/data4/val/mask/621.jpg
#   inflating: DataSet/data4/val/mask/622.jpg
#   inflating: DataSet/data4/val/mask/623.jpg
#   inflating: DataSet/data4/val/mask/624.jpg
#   inflating: DataSet/data4/val/mask/625.jpg
#   inflating: DataSet/data4/val/mask/626.jpg
#   inflating: DataSet/data4/val/mask/627.jpg
#   inflating: DataSet/data4/val/mask/628.jpg
#   inflating: DataSet/data4/val/mask/629.jpg
#   inflating: DataSet/data4/val/mask/630.jpg
#   inflating: DataSet/data4/val/mask/631.jpg
#   inflating: DataSet/data4/val/mask/632.jpg
#   inflating: DataSet/data4/val/mask/633.jpg
#   inflating: DataSet/data4/val/mask/634.jpg
#   inflating: DataSet/data4/val/mask/635.jpg
#   inflating: DataSet/data4/val/mask/636.jpg
#   inflating: DataSet/data4/val/mask/637.jpg
#   inflating: DataSet/data4/val/mask/638.jpg
#   inflating: DataSet/data4/val/mask/639.jpg
#   inflating: DataSet/data4/val/mask/640.jpg
#   inflating: DataSet/data4/val/mask/641.jpg
#   inflating: DataSet/data4/val/mask/642.jpg
#   inflating: DataSet/data4/val/mask/643.jpg
#   inflating: DataSet/data4/val/mask/644.jpg
#   inflating: DataSet/data4/val/mask/645.jpg
#   inflating: DataSet/data4/val/mask/646.jpg
#   inflating: DataSet/data4/val/mask/647.jpg
#   inflating: DataSet/data4/val/mask/648.jpg
#   inflating: DataSet/data4/val/mask/649.jpg
#   inflating: DataSet/data4/val/mask/650.jpg
#   inflating: DataSet/data4/val/mask/651.jpg
#   inflating: DataSet/data4/val/mask/652.jpg
#   inflating: DataSet/data4/val/mask/653.jpg
#   inflating: DataSet/data4/val/mask/654.jpg
#   inflating: DataSet/data4/val/mask/655.jpg
#   inflating: DataSet/data4/val/mask/656.jpg
#   inflating: DataSet/data4/val/mask/657.jpg
#   inflating: DataSet/data4/val/mask/658.jpg
#   inflating: DataSet/data4/val/mask/659.jpg
#   inflating: DataSet/data4/val/mask/660.jpg
#   inflating: DataSet/data4/val/mask/661.jpg
#   inflating: DataSet/data4/val/mask/662.jpg
#   inflating: DataSet/data4/val/mask/663.jpg
#   inflating: DataSet/data4/val/mask/664.jpg
#   inflating: DataSet/data4/val/mask/665.jpg
#   inflating: DataSet/data4/val/mask/666.jpg
#   inflating: DataSet/data4/val/mask/667.jpg
#   inflating: DataSet/data4/val/mask/668.jpg
#   inflating: DataSet/data4/val/mask/669.jpg
#   inflating: DataSet/data4/val/mask/670.jpg
#   inflating: DataSet/data4/val/mask/671.jpg
#   inflating: DataSet/data4/val/mask/672.jpg
#   inflating: DataSet/data4/val/mask/673.jpg
#   inflating: DataSet/data4/val/mask/674.jpg
#   inflating: DataSet/data4/val/mask/675.jpg
#   inflating: DataSet/data4/val/mask/676.jpg
#   inflating: DataSet/data4/val/mask/677.jpg
#   inflating: DataSet/data4/val/mask/678.jpg
#   inflating: DataSet/data4/val/mask/679.jpg
#   inflating: DataSet/data4/val/mask/680.jpg
#   inflating: DataSet/data4/val/mask/681.jpg
#   inflating: DataSet/data4/val/mask/682.jpg
#   inflating: DataSet/data4/val/mask/683.jpg
#   inflating: DataSet/data4/val/mask/684.jpg
#   inflating: DataSet/data4/val/mask/685.jpg
#   inflating: DataSet/data4/val/mask/686.jpg
#   inflating: DataSet/data4/val/mask/687.jpg
#   inflating: DataSet/data4/val/mask/688.jpg
#   inflating: DataSet/data4/val/mask/689.jpg
#   inflating: DataSet/data4/val/mask/690.jpg
#   inflating: DataSet/data4/val/mask/691.jpg
#   inflating: DataSet/data4/val/mask/692.jpg
#   inflating: DataSet/data4/val/mask/693.jpg
#   inflating: DataSet/data4/val/mask/694.jpg
#   inflating: DataSet/data4/val/mask/695.jpg
#   inflating: DataSet/data4/val/mask/696.jpg
#   inflating: DataSet/data4/val/mask/697.jpg
#   inflating: DataSet/data4/val/mask/698.jpg
#   inflating: DataSet/data4/val/mask/699.jpg

# %%
# !cp /content/gdrive/'My Drive'/Files/label_class_dict.csv .

# %%
# !cp /content/gdrive/'My Drive'/Files/best_model_1.pth .
# !cp /content/gdrive/'My Drive'/Files/best_model_2.pth .
# !cp /content/gdrive/'My Drive'/Files/best_model.pth .

# %% [markdown]
# ### Установка библиотек

# %%
#!pip uninstall -y segmentation-models-pytorch

# %%
# Catalyst
# !pip install catalyst==20.10.1

# for augmentations
# !pip install albumentations==0.4.3

# for pretrained segmentation models for PyTorch
# !pip install segmentation-models-pytorch==0.1.0

# for TTA
# !pip install ttach==0.0.2

# for tensorboard
# !pip install tensorflow

# if Your machine support Apex FP16, uncomment this 3 lines below
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex
# is_fp16_used = True
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catalyst==20.10.1 in /usr/local/lib/python3.9/dist-packages (20.10.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (7.34.0)
# Requirement already satisfied: tensorboard>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (2.12.1)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (5.13.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (4.65.0)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (2.0.0+cu118)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (2.6)
# Requirement already satisfied: pandas>=0.22 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (1.5.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (3.7.1)
# Requirement already satisfied: GitPython>=3.1.1 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (3.1.31)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (23.0)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (1.22.4)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.9/dist-packages (from catalyst==20.10.1) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython>=3.1.1->catalyst==20.10.1) (4.0.10)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.22->catalyst==20.10.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.22->catalyst==20.10.1) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.1.0->catalyst==20.10.1) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20->catalyst==20.10.1) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20->catalyst==20.10.1) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20->catalyst==20.10.1) (1.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (1.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (67.6.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (3.20.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (2.17.2)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (1.53.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=1.14.0->catalyst==20.10.1) (1.8.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.1.0->catalyst==20.10.1) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.1.0->catalyst==20.10.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.1.0->catalyst==20.10.1) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.1.0->catalyst==20.10.1) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.1.0->catalyst==20.10.1) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.1.0->catalyst==20.10.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.1.0->catalyst==20.10.1) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.1.0->catalyst==20.10.1) (16.0.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (2.14.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from ipython->catalyst==20.10.1) (0.18.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catalyst==20.10.1) (1.0.7)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.1->catalyst==20.10.1) (5.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14.0->catalyst==20.10.1) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14.0->catalyst==20.10.1) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14.0->catalyst==20.10.1) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.14.0->catalyst==20.10.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.14.0->catalyst==20.10.1) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catalyst==20.10.1) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython->catalyst==20.10.1) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=1.14.0->catalyst==20.10.1) (6.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython->catalyst==20.10.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->catalyst==20.10.1) (0.2.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst==20.10.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst==20.10.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst==20.10.1) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst==20.10.1) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.14.0->catalyst==20.10.1) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.1.0->catalyst==20.10.1) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.14.0->catalyst==20.10.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.14.0->catalyst==20.10.1) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: albumentations==0.4.3 in /usr/local/lib/python3.9/dist-packages (0.4.3)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from albumentations==0.4.3) (4.7.0.72)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from albumentations==0.4.3) (6.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.9/dist-packages (from albumentations==0.4.3) (1.22.4)
# Requirement already satisfied: imgaug<0.2.7,>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from albumentations==0.4.3) (0.2.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from albumentations==0.4.3) (1.10.1)
# Requirement already satisfied: scikit-image>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (1.16.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (8.4.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (2023.3.21)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (23.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (1.4.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: segmentation-models-pytorch==0.1.0 in /usr/local/lib/python3.9/dist-packages (0.1.0)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.9/dist-packages (from segmentation-models-pytorch==0.1.0) (0.7.4)
# Requirement already satisfied: efficientnet-pytorch>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from segmentation-models-pytorch==0.1.0) (0.7.1)
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from segmentation-models-pytorch==0.1.0) (0.15.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (4.65.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (2.0.0+cu118)
# Requirement already satisfied: munch in /usr/local/lib/python3.9/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (2.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (8.4.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (3.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (3.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ttach==0.0.2 in /usr/local/lib/python3.9/dist-packages (0.0.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (0.0.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %% [markdown]
# ###  Импорты библиотек

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

# %%
import albumentations as albu

# %%
import torch
import numpy as np
import segmentation_models_pytorch as smp
from glob import glob
from PIL import Image
 #print(torch.cuda.get_device_name(0))
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ### Пути к данным

# %%
DATA_DIR = './DataSet/data3/'

# %%
path_save = './data/img.jpg'


path_csv = os.path.join('./label_class_dict.csv')

path_model_best = os.path.join('./best_model.pth')



x_train_dir = os.path.join(DATA_DIR, 'train/image/')
y_train_dir = os.path.join(DATA_DIR, 'train/mask/')

x_valid_dir = os.path.join(DATA_DIR, 'val/image/')
y_valid_dir = os.path.join(DATA_DIR, 'val/mask/')

x_test_dir = os.path.join(DATA_DIR, 'test/image/')
y_test_dir = os.path.join(DATA_DIR, 'test/mask/')

# %% [markdown]
# ### Функции просмотра изображений и масок

# %%
# Просмотр изображений
# вывод несколько изображений 
def display(**images):
    
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()


# Вывод изображения, оригинальной маски и предсказанной маски
def display_img(img, mask, pred):
    mask = mask.transpose(1, 2, 0).astype('float32')
    mask = mask[:,:,0]
    #img = np.reshape(img,(256,256,3))
    #mask = np.reshape(mask,(256,256,3))
    #pred = np.reshape(pred,(256,256,1))
    fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,10))
    ax1.imshow(img)
    ax1.axis('off')
    ax2.imshow(mask,  cmap="gray")
    ax2.axis('off')
    ax3.imshow(pred,  cmap="gray")
    ax3.axis('off')

# Функции просмотра изображений и маски
def display_img_mask(img, mask):

    fig,(ax1,ax2) = plt.subplots(1,2,figsize=(16,5))
    ax1.imshow(img)
    ax1.axis('off')
    ax2.imshow(mask,  cmap="gray")
    ax2.axis('off')
 
# Функции просмотра изображений
def display_img_mask_newMask(img, mask, new_mask):

    fig,(ax1,ax2, ax3) = plt.subplots(1,3,figsize=(15,10))
    ax1.imshow(img)
    ax1.axis('off')
    ax2.imshow(mask,  cmap="gray")
    ax2.axis('off')
    ax3.imshow(new_mask,  cmap="gray")
    ax3.axis('off')



def display_mask(img):
  fig, ax = plt.subplots()
  ax.imshow(img,  cmap="gray")
  fig.set_figwidth(6)    #  ширина и
  fig.set_figheight(6)    #  высота "Figure"
  plt.show()

# %% [markdown]
# ### DataSet
#
# Вспомогательный класс  для извлечения предварительной обработки данных
# https://pytorch.org/docs/stable/data

# %%
# from sklearn.model_selection import train_test_split

# %%
class Dataset(BaseDataset):
    """
    
    images_dir: Путь к папке с изображениями

    masks_dir: Путь к папке с масками
    
    """
    CLASSES = ['window', 'backgound']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask1 = cv2.imread(self.masks_fps[i], cv2.IMREAD_GRAYSCALE)
        ret, mask = cv2.threshold(mask1, 127, 255, cv2.THRESH_BINARY)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)

# %% [markdown]
# #### просмотр   изображения и маски

# %%
dataset = Dataset(x_train_dir, y_train_dir, classes=['window'])
#dataset = Dataset(x_train_dir, y_train_dir)
image, mask = dataset[0] 

display(
    image=image, 
    mask=mask,
)

# %%
display_img_mask(image, mask.squeeze())

# %% [markdown]
# ### Аугментация

# %%
def get_training_augmentation():
    train_transform = [
        albu.HorizontalFlip(p=0.5),
        albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),
        albu.PadIfNeeded(min_height=y_size, min_width=x_size, always_apply=True, border_mode=0),
        albu.RandomCrop(height=y_size, width=x_size, always_apply=True),
        albu.IAAAdditiveGaussianNoise(p=0.2),
        albu.IAAPerspective(p=0.5),
        albu.OneOf(
            [
                albu.CLAHE(p=1),
                albu.RandomBrightness(p=1),
                albu.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.IAASharpen(p=1),
                albu.Blur(blur_limit=3, p=1),
                albu.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.RandomContrast(p=1),
                albu.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation():
    test_transform = [
        albu.PadIfNeeded(y_size, x_size)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %%
# Просмотр применения аугментации

augmented_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    classes=['window'],
)


for i in range(3):
    image, mask = augmented_dataset[5]
    display(image=image, mask=mask.squeeze(-1))

# %%
for i in range(3):
    image, mask = augmented_dataset[5]
    display_img_mask(image, mask=mask.squeeze(-1))

# %% [markdown]
# ## Модель

# %%
#
#   Создаём модель
#
#   Энкодер - resnet50
#
#   Предобученные веса -  imagenet
#

model = smp.FPN(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    classes=len(CLASSES), 
    activation=ACTIVATION,
)

# %%
# ЗАГРУЗКА МОДЕЛИ (Ранее сохранённой натренированной модели)
model = torch.load('./best_model_2.pth', map_location=torch.device(DEVICE))

# %%
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %% [markdown]
# фомируем датасеты

# %%
# тренировачный датасет
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

# проверочный датасет
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

# %%
# Загрузка датасетов
train_loader = DataLoader(train_dataset, batch_size= BATCH_SIZE, shuffle=True, num_workers=1)
valid_loader = DataLoader(valid_dataset, batch_size= BATCH_SIZE, shuffle=False, num_workers=1)

# %%
loss = smp.utils.losses.DiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.001),
])

# %%
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %% [markdown]
# ## Тренировка модели

# %%
# ТРЕНИРОВКА МОДЕЛИ

max_score = 0

EPOCHS = 42

for i in range(0, EPOCHS):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, './best_model_2.pth')
        print('Model saved!')
        
    if i % 20 == 0:
        optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr']/10
        print('Изменение - learning rate: ', optimizer.param_groups[0]['lr'])
# Out:
# Epoch: 0
# train: 100%|██████████| 239/239 [01:03<00:00,  3.76it/s, dice_loss - 0.2453, iou_score - 0.6089]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.96it/s, dice_loss - 0.2321, iou_score - 0.6246]
# Model saved!
# Изменение - learning rate:  0.0001
#
# Epoch: 1
# train: 100%|██████████| 239/239 [00:57<00:00,  4.18it/s, dice_loss - 0.211, iou_score - 0.6537]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.16it/s, dice_loss - 0.2009, iou_score - 0.667]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1978, iou_score - 0.6722]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.90it/s, dice_loss - 0.192, iou_score - 0.6793]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1918, iou_score - 0.6805]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.53it/s, dice_loss - 0.1898, iou_score - 0.6823]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1834, iou_score - 0.6919]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.36it/s, dice_loss - 0.1863, iou_score - 0.6873]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1835, iou_score - 0.6918]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.06it/s, dice_loss - 0.1876, iou_score - 0.6856]
#
# Epoch: 6
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1794, iou_score - 0.6978]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.32it/s, dice_loss - 0.18, iou_score - 0.6963]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 239/239 [00:57<00:00,  4.19it/s, dice_loss - 0.1756, iou_score - 0.7033]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.06it/s, dice_loss - 0.1786, iou_score - 0.6982]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 239/239 [00:57<00:00,  4.18it/s, dice_loss - 0.1745, iou_score - 0.7047]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.32it/s, dice_loss - 0.18, iou_score - 0.6963]
#
# Epoch: 9
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1718, iou_score - 0.7086]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.22it/s, dice_loss - 0.1749, iou_score - 0.7036]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 239/239 [00:56<00:00,  4.20it/s, dice_loss - 0.1689, iou_score - 0.7127]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.93it/s, dice_loss - 0.1776, iou_score - 0.6997]
#
# Epoch: 11
# train: 100%|██████████| 239/239 [00:57<00:00,  4.18it/s, dice_loss - 0.1671, iou_score - 0.7153]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.31it/s, dice_loss - 0.1768, iou_score - 0.7008]
#
# Epoch: 12
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1651, iou_score - 0.7182]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.04it/s, dice_loss - 0.1766, iou_score - 0.701]
#
# Epoch: 13
# train: 100%|██████████| 239/239 [00:57<00:00,  4.14it/s, dice_loss - 0.1631, iou_score - 0.7209]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.19it/s, dice_loss - 0.1712, iou_score - 0.7088]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1638, iou_score - 0.72]
# valid: 100%|██████████| 101/101 [00:08<00:00, 12.18it/s, dice_loss - 0.1709, iou_score - 0.7095]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 239/239 [00:56<00:00,  4.19it/s, dice_loss - 0.1611, iou_score - 0.724]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.66it/s, dice_loss - 0.1726, iou_score - 0.7069]
#
# Epoch: 16
# train: 100%|██████████| 239/239 [00:57<00:00,  4.14it/s, dice_loss - 0.1597, iou_score - 0.7259]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.19it/s, dice_loss - 0.1708, iou_score - 0.7095]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1561, iou_score - 0.7314]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.00it/s, dice_loss - 0.1747, iou_score - 0.7037]
#
# Epoch: 18
# train: 100%|██████████| 239/239 [00:57<00:00,  4.12it/s, dice_loss - 0.1578, iou_score - 0.7288]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.14it/s, dice_loss - 0.1715, iou_score - 0.7083]
#
# Epoch: 19
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1545, iou_score - 0.7337]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.67it/s, dice_loss - 0.1699, iou_score - 0.7107]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 239/239 [00:57<00:00,  4.17it/s, dice_loss - 0.1534, iou_score - 0.7354]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.84it/s, dice_loss - 0.1683, iou_score - 0.7131]
# Model saved!
# Изменение - learning rate:  1e-05
#
# Epoch: 21
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1493, iou_score - 0.7414]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.76it/s, dice_loss - 0.1635, iou_score - 0.7202]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 239/239 [00:56<00:00,  4.22it/s, dice_loss - 0.1468, iou_score - 0.745]
# valid: 100%|██████████| 101/101 [00:08<00:00, 12.16it/s, dice_loss - 0.1639, iou_score - 0.7195]
#
# Epoch: 23
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1477, iou_score - 0.7438]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.28it/s, dice_loss - 0.1627, iou_score - 0.7213]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 239/239 [00:57<00:00,  4.17it/s, dice_loss - 0.1467, iou_score - 0.7451]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.02it/s, dice_loss - 0.1635, iou_score - 0.7201]
#
# Epoch: 25
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1437, iou_score - 0.7498]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.20it/s, dice_loss - 0.163, iou_score - 0.7209]
#
# Epoch: 26
# train: 100%|██████████| 239/239 [00:57<00:00,  4.17it/s, dice_loss - 0.1457, iou_score - 0.7468]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.04it/s, dice_loss - 0.1634, iou_score - 0.7203]
#
# Epoch: 27
# train: 100%|██████████| 239/239 [00:57<00:00,  4.17it/s, dice_loss - 0.1439, iou_score - 0.7495]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.35it/s, dice_loss - 0.1633, iou_score - 0.7205]
#
# Epoch: 28
# train: 100%|██████████| 239/239 [00:57<00:00,  4.14it/s, dice_loss - 0.1443, iou_score - 0.7489]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.77it/s, dice_loss - 0.1632, iou_score - 0.7206]
#
# Epoch: 29
# train: 100%|██████████| 239/239 [00:57<00:00,  4.14it/s, dice_loss - 0.1439, iou_score - 0.7495]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.39it/s, dice_loss - 0.1643, iou_score - 0.719]
#
# Epoch: 30
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.144, iou_score - 0.7493]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.36it/s, dice_loss - 0.1638, iou_score - 0.7196]
#
# Epoch: 31
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1421, iou_score - 0.7522]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.97it/s, dice_loss - 0.1632, iou_score - 0.7206]
#
# Epoch: 32
# train: 100%|██████████| 239/239 [00:57<00:00,  4.13it/s, dice_loss - 0.1436, iou_score - 0.7499]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.18it/s, dice_loss - 0.1624, iou_score - 0.7217]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1434, iou_score - 0.7504]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.93it/s, dice_loss - 0.1612, iou_score - 0.7236]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1434, iou_score - 0.7503]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.28it/s, dice_loss - 0.1628, iou_score - 0.7211]
#
# Epoch: 35
# train: 100%|██████████| 239/239 [00:57<00:00,  4.13it/s, dice_loss - 0.1439, iou_score - 0.7495]
# valid: 100%|██████████| 101/101 [00:08<00:00, 12.08it/s, dice_loss - 0.1625, iou_score - 0.7215]
#
# Epoch: 36
# train: 100%|██████████| 239/239 [00:57<00:00,  4.18it/s, dice_loss - 0.1442, iou_score - 0.7493]
# valid: 100%|██████████| 101/101 [00:08<00:00, 11.68it/s, dice_loss - 0.1628, iou_score - 0.7211]
#
# Epoch: 37
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.1422, iou_score - 0.7519]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.14it/s, dice_loss - 0.1631, iou_score - 0.7208]
#
# Epoch: 38
# train: 100%|██████████| 239/239 [00:57<00:00,  4.16it/s, dice_loss - 0.1413, iou_score - 0.7536]
# valid: 100%|██████████| 101/101 [00:07<00:00, 12.77it/s, dice_loss - 0.1628, iou_score - 0.7211]
#
# Epoch: 39
# train: 100%|██████████| 239/239 [00:57<00:00,  4.14it/s, dice_loss - 0.1425, iou_score - 0.7517]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.15it/s, dice_loss - 0.1635, iou_score - 0.7202]
#
# Epoch: 40
# train: 100%|██████████| 239/239 [00:57<00:00,  4.17it/s, dice_loss - 0.1427, iou_score - 0.7514]
# valid: 100%|██████████| 101/101 [00:07<00:00, 13.01it/s, dice_loss - 0.1624, iou_score - 0.7218]
# Изменение - learning rate:  1.0000000000000002e-06
#
# Epoch: 41
# train: 100%|██████████| 239/239 [00:57<00:00,  4.15it/s, dice_loss - 0.142, iou_score - 0.7525]
# valid: 100%|██████████| 101/101 [00:09<00:00, 11.16it/s, dice_loss - 0.1628, iou_score - 0.7211]

# %% [markdown]
# ## ПРОВЕРКА НА ТЕСТОВОМ НАБОРЕ

# %%
# ЗАГРУЗКА МОДЕЛИ
model = torch.load('./best_model_2.pth', map_location=torch.device(DEVICE))

# %%
# формирование тестового датасета
test_dataset1 = Dataset(
    x_test_dir, 
    y_test_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

# Загрузка тестового датасета
test_dataloader = DataLoader(test_dataset)

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)
# Out:
# /usr/local/lib/python3.9/dist-packages/albumentations/augmentations/transforms.py:2907: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   warnings.warn(

# %%
# Оценка модели тестовым набором
test_epoch = smp.utils.train.ValidEpoch(
    model=model,
    loss=loss,
    metrics=metrics,
    device=DEVICE,
)

logs = test_epoch.run(test_dataloader)
# Out:
# valid: 100%|██████████| 251/251 [00:05<00:00, 48.96it/s, dice_loss - 0.1263, iou_score - 0.7808]

# %% [markdown]
# ###  Просмотр предсказанных изображений

# %%
# загрузка тренировачного датасета
test_dataset_vis = Dataset(
    x_test_dir, y_test_dir, 
    classes=CLASSES,
)

# %%
for i in range(10):
    n = np.random.choice(len(test_dataset))
    
    image_vis = test_dataset_vis[n][0].astype('uint8')
    image, gt_mask = test_dataset[n]
    
    gt_mask = gt_mask.squeeze()
    
    x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    pr_mask = model.predict(x_tensor)
    pr_mask = (pr_mask.squeeze().cpu().numpy().round())

    display_img(image_vis, gt_mask, pr_mask )
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## ПОДСЧЁТ КОЛИЧЕСТВА ОКОН

# %% [markdown]
# #### Вспомогательные функции для подсчёта окон

# %%
# функция проверяет принадлежит ли точка ранее найденному окну?
def belong(x, y, set_point: list):
    if (set_point[0] <= x <= set_point[2]) and (set_point[1] <= y <= set_point[3]):
        return True
    else:
        return False

# %%
# Поиск всех точек принадлежащих новому окну
def search_points(a, b, img5):
    img = img5
    # list_points_window = [0, 0, 0, 0]  # Список содержащий угловые точки окна
    x0 = a   # точка начала движения
    y0 = b
    
    y1 = b    # текущий номер верхней строки окна
    x1 = a    # текущий номер левого столбца окна
    y2 = b    # текущий номер нижней строки окна
    x2 = a    # текущий номер правого столбца окна
    
    x = a     #  текущее положение точки
    y = b
    
    mov = 'RIGHT'   #   направление движения (начинаем движение вправо)
    flag_round = False
    
    while flag_round == False:  # Пока не вернулись в исходную точку, обходим точки окна          
        if mov == 'NONE': # Если единственный пиксель чёрный
            continue
        if mov == 'RIGHT': # движемся вправо
            list1 = right_mov(x, y, img)  # выбираем новую точку и направление движения
            xx = list1[0] 
            if x1 > list1[0]:
                x1 = list1[0]
            if x2 < list1[0]:
                x2 = list1[0]
            if y1 > list1[1]:
                y1 = list1[1]
            if y2 < list1[1]:
                y2 = list1[1]
            x = list1[0]
            y = list1[1]
            mov = list1[2]
            flag_round =( x0 == x and y0 == y)
            continue          

        if mov == 'LEFT': # движемся влево
            list1 = left_mov(x, y, img)  # выбираем новую точку и направление движения  
            if x1 > list1[0]:
                x1 = list1[0]
            if x2 < list1[0]:
                x2 = list1[0]
            if y1 > list1[1]:
                y1 = list1[1]
            if y2 < list1[1]:
                y2 = list1[1]
            x = list1[0]
            y = list1[1]
            mov = list1[2]
            flag_round =( x0 == x and y0 == y)
            continue
                        
        if mov == 'DOWN': # движемся вниз
            list1 = down_mov(x, y, img)  # выбираем новую точку и направление движения 
         
            if x1 > list1[0]:
                x1 = list1[0]
            if x2 < list1[0]:
                x2 = list1[0]
            if y1 > list1[1]:
                y1 = list1[1]
            if y2 < list1[1]:
                y2 = list1[1]
            x = list1[0]
            y = list1[1]
            mov = list1[2]
            flag_round =( x0 == x and y0 == y)
            continue     

        if mov == 'UP': # движемся вверх
            list1 = up_mov(x, y, img)  # выбираем новую точку и направление движения
            if x1 > list1[0]:
                x1 = list1[0]
            if x2 < list1[0]:
                x2 = list1[0]
            if y1 > list1[1]:
                y1 = list1[1]
            if y2 < list1[1]:
                y2 = list1[1]
            x = list1[0]
            y = list1[1]
            mov = list1[2]
            flag_round =( x0 == x and y0 == y)
            continue  
            
    list_points_window = [x1, y1, x2, y2] 

    vv = 0
    return  list_points_window

# %%
# функция движения вправо
def right_mov(x, y, img):  #  Выбираем направление  продолжения движения
    size = 255
    if y  > 0 and img[x, y - 1] == 0:
        mov = 'UP'
        y = y - 1
        return [x, y, mov]
    if x < size and img[x + 1, y] == 0:
        mov = 'RIGHT'
        x = x + 1
        return [x, y, mov]  
    if y < size and img[x, y + 1] == 0:
        mov = 'DOWN'
        y = y + 1
        return [x, y, mov]    
    if x > 0 and img[x - 1, y] == 0:
        mov = 'LEFT'
        x = x - 1
        return [x, y, mov]
    else:
        mov = 'NONE'
        return [x, y, mov]
    
# функция движения влево
def left_mov(x, y, img):
    size = 255
    if y < size and img[x, y + 1] == 0:
        mov = 'DOWN'
        y = y + 1
        return [x, y, mov]    
    if x > 0 and img[x - 1, y] == 0:
        mov = 'LEFT'
        x = x - 1
        return [x, y, mov] 
    if y > 0 and img[x, y - 1] == 0:
        mov = 'UP'
        y = y - 1
        return [x, y, mov] 
    if x < size and img[x + 1, y] == 0:
        mov = 'RIGHT'
        x = x + 1
        return [x, y, mov] 
    else:
        mov = 'NONE'
        return [x, y, mov]    

# функция движения вниз
def down_mov(x, y, img):
    size = 255
    if x < size and img[x + 1, y] == 0:
        mov = 'RIGHT'
        x = x + 1
        return [x, y, mov]  
    if y < size and img[x, y + 1] == 0:
        mov = 'DOWN'
        y = y + 1
        return [x, y, mov]    
    if x > 0 and img[x - 1, y] == 0:
        mov = 'LEFT'
        x = x - 1
        return [x, y, mov] 
    if y > 0 and img[x, y - 1] == 0:
        mov = 'UP'
        y = y - 1
        return [x, y, mov]    
    else:
        mov = 'NONE'
        return [x, y, mov]
    
# функция движения вверх
def up_mov(x, y, img): 
    size = 255
    if x > 0 and img[x - 1, y] == 0:
        mov = 'LEFT'
        x = x - 1
        return [x, y, mov] 
    if y > 0 and img[x, y - 1] == 0:
        mov = 'UP'
        y = y - 1
        return [x, y, mov] 
    if x < size and img[x + 1, y] == 0:
        mov = 'RIGHT'
        x = x + 1
        return [x, y, mov] 
    if y < size and img[x, y + 1] == 0:
        mov = 'DOWN'
        y = y + 1
        return [x, y, mov]    
    else:
        mov = 'NONE'
        return [x, y, mov]

# %%
# функция преобразования изображения
def funcImg(img):
  size_x, size_y =  img.shape
  array_img = np.zeros((size_x, size_y))
  for x in range(size_x):
    for y in range(size_y):
      if img[x, y] == 0:
        array_img[x, y] = 255
      else:
        array_img[x, y] = 0
  return array_img

# %%
def func_mask(img, array_mask_windows):  
  #size_x, size_y, ee = img.shape
  size_x, size_y = img.shape
  img_new = np.ones((size_x, size_y))
  for x in range(size_x):
      for y in range(size_y):
          for list_w in array_mask_windows:
              flag = belong(x, y, list_w)
              if flag == True:
                  img_new[x,y] = 0
                  break
              else:
                  img_new[x,y] = 255
  return img_new

# %% [markdown]
# ### Основная функция подсчёта

# %%
# функция подсчёта возвращает количество окон и список угловых точек всех окон
def calc_windows(img):
    list_windows = []    # Список содеражщий информацию о всех окнах
    list_points_window = []  # Список содержащий угловые точки окна
    count_windows = 0 # количество найденных окон
    #img2 = img[:,:,0]
    img2 = img
    size_x, size_y = img2.shape
    flag = False  # Флаг цвета точки
    for x in range(size_x):
        for y in range(size_y):
            if img2[x, y] == 0:
                flag2 = False  # флаг принадлежит ли текущая точка ранее найденному окну?
                if list_windows:                   
                    for list_w in list_windows:               
                        flag2 = belong(x, y, list_w)
                        if flag2==True:   # Если точка принадлежит окну, выходим
                            break
                if flag2==False:  # b
                    count_windows = count_windows + 1
                    list_points_window = search_points(x, y, img2) # ищем окно которому принадлежит точка 
                    list_windows.append(list_points_window)      # добавляем в список окно  
                   
        
    return  count_windows, list_windows

# %%
# функция сегментации
def segmenation_fasads(num):
  image, gt_mask = test_dataset[num]
  x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
  pr_mask = model.predict(x_tensor)
  pr_mask1 = (pr_mask.squeeze().cpu().numpy().round())
  image1 = image.transpose(1, 2, 0).astype('float32')
  img_mask = funcImg(pr_mask1)

  # array_mask_windows - массив угловых точек окон
  # count_windows   -  количество окон
  count_windows, array_mask_windows = calc_windows(img_mask)
  print('Количество окон: ', count_windows)
  mask_new = func_mask(img_mask, array_mask_windows)
  display_img_mask_newMask(image1, img_mask, mask_new)
  #ret,img11 = cv2.threshold(pr_mask,127,255,cv2.THRESH_BINARY)



  img_save = cv2.imwrite(path_save, img_mask)

# %% [markdown]
# # ПРОВЕРКА РАБОТЫ

# %%
#
#    Обработем изображение
#
#  1) Вывод количества окон на изображении
#  2) Само изображение
#  3) сгенерированное изображение маски
#  4) улучшенное изображение полученной маски
#
#
#   num - Номер в тестовом датасете
#

num = 0
segmenation_fasads(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e10a224d8ce> in <cell line: 14>()
#      12
#      13 num = 0
# ---> 14 segmenation_fasads(num)
#
# NameError: name 'segmenation_fasads' is not defined

# %%
import gc
del valid_epoch
gc.collect()   
del train_epoch
del train_loader
del valid_loader
del train_dataset
gc.collect()
# Out:
# 0

# %%
torch.cuda.empty_cache()
